# %%
import bs4
import urllib.request as urllib_request
import pandas

print("BeautifulSoup ->", bs4.__version__)
print("urllib ->", urllib_request.__version__)
print("pandas ->", pandas.__version__)
# Out:
# BeautifulSoup -> 4.10.0
# urllib -> 3.8
# pandas -> 1.3.4

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

url = 'https://adotar.com.br/animais.aspx?cc=1484&cn=ms-campo-grande&finalidade=Adocao&tipo=Cao&porte=Medio'

response = urlopen(url)
html = response.read()

soup = BeautifulSoup(html, 'html.parser')

soup
# Out:
# <!DOCTYPE html>
#
# <html lang="pt-br">
# <head><meta content="424936937573966" property="fb:app_id"/><meta content="website" property="og:type"/><meta content="pt-br" http-equiv="content-language"/><meta content="initial-scale=1.0" name="viewport"/><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><title>
# 	Cachorros para adoção em MS - Campo Grande - Procure 1 Amigo
# </title><meta content="Cachorros para adoção em MS - Campo Grande - Procure 1 Amigo" name="title"/><meta content="Veja Cachorros para adoção em MS - Campo Grande - Procure 1 Amigo - cachorros e gatos de ONGs de proteção animal do Brasil - Adoção, doação e procura de cães e gatos" name="description"/><meta content="Cachorros para adoção em MS - Campo Grande - Procure 1 Amigo" name="keywords"/><meta content="Cachorros para adoção em MS - Campo Grande - Procure 1 Amigo" name="og:title" property="og:title"/><meta content="Veja Cachorros para adoção em MS - Campo Grande - Procure 1 Amigo - cachorros e gatos de ONGs de proteção animal do Brasil - Adoção, doação e procura de cães e gatos" name="og:description" property="og:description"/><meta content="https://adotar.com.br/imagens/amigos-cao-e-gato-dfaff.jpg" name="og:image" property="og:image"/><meta content="https://adotar.com.br/animais.aspx?cc=1484&amp;cn=ms-campo-grande&amp;finalidade=Adocao&amp;tipo=Cao&amp;porte=Medio" name="og:url" property="og:url"/><meta content="Procure 1 Amigo" name="og:site_name" property="og:site_name"/><meta content="424936937573966" name="fb:app_id" property="fb:app_id"/><meta content="website" name="og:type" property="og:type"/><meta content="@procure1amigo" name="twitter:site"/><meta content="Cachorros para adoção em MS - Campo Grande - Procure 1 Amigo" name="twitter:title"/><meta content="Veja Cachorros para adoção em MS - Campo Grande - Procure 1 Amigo - cachorros e gatos de ONGs de proteção animal do Brasil - Adoção, doação e procura de cães e gatos" name="twitter:description"/><meta content="https://adotar.com.br/imagens/amigos-cao-e-gato-dfaff.jpg" name="twitter:image"/><meta content="Procure1Amigo" name="apple-mobile-web-app-title"/><link href="//adotar.com.br/icones/apple-touch-icon-196x196-precomposed.png" rel="shortcut icon" sizes="196x196"/><link href="//adotar.com.br/icones/apple-touch-icon-152x152-precomposed.png" rel="apple-touch-icon-precomposed" sizes="152x152"/><link href="//adotar.com.br/icones/apple-touch-icon-144x144-precomposed.png" rel="apple-touch-icon-precomposed" sizes="144x144"/><link href="//adotar.com.br/icones/apple-touch-icon-120x120-precomposed.png" rel="apple-touch-icon-precomposed" sizes="120x120"/><link href="//adotar.com.br/icones/apple-touch-icon-114x114-precomposed.png" rel="apple-touch-icon-precomposed" sizes="114x114"/><link href="//adotar.com.br/icones/apple-touch-icon-76x76-precomposed.png" rel="apple-touch-icon-precomposed" sizes="76x76"/><link href="//adotar.com.br/icones/apple-touch-icon-72x72-precomposed.png" rel="apple-touch-icon-precomposed" sizes="72x72"/><link href="//adotar.com.br/icones/apple-touch-icon-60x60-precomposed.png" rel="apple-touch-icon-precomposed" sizes="60x60"/><link href="//adotar.com.br/icones/apple-touch-icon-57x57-precomposed.png" rel="apple-touch-icon-precomposed" sizes="57x57"/><link href="//adotar.com.br/icones/apple-touch-icon-60x60-precomposed.png" rel="apple-touch-icon-precomposed"/><link href="//adotar.com.br/icones/apple-touch-icon-16x16-precomposed.png" rel="shortcut icon" sizes="16x16"/><link href="//adotar.com.br/icones/apple-touch-icon-76x76-precomposed.png" rel="apple-touch-icon" sizes="76x76"/><link href="//adotar.com.br/icones/apple-touch-icon-60x60-precomposed.png" rel="apple-touch-icon" sizes="60x60"/><link href="//adotar.com.br/icones/apple-touch-icon-60x60-precomposed.png" rel="apple-touch-icon"/><link href="//adotar.com.br/icones/iphoneSplashScreen.png" media="(device-width: 320px)" rel="apple-touch-startup-image"/><link href="//adotar.com.br/icones/iphone4SplashScreen.png" media="(device-width: 320px) and (-webkit-device-pixel-ratio: 2)" rel="apple-touch-startup-image"/><link href="//adotar.com.br/icones/iphone5SplashScreen.png" media="(device-height: 568px)" rel="apple-touch-startup-image"/><meta content="yes" name="apple-mobile-web-app-capable"/><meta content="yes" name="mobile-web-app-capable"/><meta content="black" name="apple-mobile-web-app-status-bar-style ...
# <script type="text/javascript">
#         var endereco = window.location.href;
#         var veioModal = false;
#         if (endereco != null && endereco.toLowerCase().includes("modal=1")) {
#             //console.log("veio modal");
#             veioModal = true;
#         }
#         else {
#
#             var googletag = googletag || {};
#             googletag.cmd = googletag.cmd || [];
#             (function () {
#                 var gads = document.createElement('script');
#                 gads.async = true;
#                 gads.type = 'text/javascript';
#                 var useSSL = 'https:' == document.location.protocol;
#                 gads.src = (useSSL ? 'https:' : 'http:') +
#                     '//www.googletagservices.com/tag/js/gpt.js';
#                 var node = document.getElementsByTagName('script')[0];
#                 node.parentNode.insertBefore(gads, node);
#             })();
#
#
#
#             googletag.cmd.push(function () {
#                 googletag.defineSlot('/75766867/Movel-Top', [320, 50], 'div-gpt-ad-1431185685094-0').addService(googletag.pubads());
#                 googletag.defineSlot('/75766867/MovelRodape', [300, 250], 'div-gpt-ad-1431185685094-1').addService(googletag.pubads());
#                 googletag.pubads().enableSingleRequest();
#                 googletag.enableServices();
#             });
#
#         }
#     </script>
# <script defer="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <link href="/manifest.json" rel="manifest"/>
# <link href="https://adotar.com.br/animais.aspx?cc=1484&amp;cn=ms-campo-grande&amp;finalidade=Adocao&amp;tipo=Cao&amp;porte=Medio" rel="canonical"/></head>
# <body id="Body">
# <div class="max-centraliza">
# <form action="./animais.aspx?cc=1484&amp;cn=ms-campo-grande&amp;finalidade=Adocao&amp;tipo=Cao&amp;porte=Medio" id="form1" method="post">
# <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="..."/>
# <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="736D0F40"/>
# <input id="__EVENTVALIDATION" name="__EVENTVALIDATION" type="hidden" value="..."/>
# <div id="boxTopo">
# <div class="max-centraliza">
# <img alt="Menu" border="0" id="botaoMenu" src="/imagens/menu_botao.png"/>
# <a href="/" id="HyperLinkLogo" title="Procure 1 Amigo - Animais para Adoção, doação e procura de cachorros e gatos"><img alt="Procure 1 Amigo - Animais para Adoção, doação e procura de cachorros e gatos" border="0" id="logo-procure-master" src="/imagens/logo.png"/></a>
# <div id="boxTopoDireita">
# <span id="LabelPaginaAtual"><i class="fa fa-heart"></i> <u>Adoção</u></span>
# </div>
# <!--<a title="Ajuda para adotar, doar e procurar" href='javascript:;' id="quero-ajuda"><i class="fa fa-question-circle" aria-hidden="true"></i></a>-->
# </div>
# </div>
# <div id="menuPrincipal">
# <ul>
# <li><a href="/?cc=1484&amp;cn=ms-campo-grande&amp;">Início</a></li>
# <!--<li><a href="painel">Cadastrar animal</a></li>-->
# <li><a href="/animais.aspx?cc=1484&amp;cn=ms-campo-grande&amp;finalidade=Adocao">Animais para adoção</a></li>
# <li><a href="/animais.aspx?cc=1484&amp;cn=ms-campo-grande&amp;finalidade=Procura-Perdido">Animais perdidos</a></li>
# <li><a href="/animais.aspx?cc=1484&amp;cn=ms-campo-grande&amp;finalidade=Encontrado">Animais encontrados</a></li>
# <li><a href="/busca.aspx?cc=1484&amp;cn=ms-campo-grande">Busca detalhada</a></li>
# <li><a href="/eventos.aspx">Eventos</a></li>
# <li><a href="https://loja.procure1amigo.com.br/" rel="noopener" target="_blank">Loja</a></li>
# <li><a href="/blog.aspx">Blog</a></li>
# <li><a href="/fale_conosco.aspx">Contato</a></li>
# <li><a href="/entrar.aspx">Cadastrar animal</a></li>
# <li><a href="/cadastro_finaliza.aspx">Ajude-nos</a></li>
# <li><a href="/quem_somos.aspx">Quem Somos</a></li>
# <!--<li><a href='//adotar.com.br/?fixa=1'>Site desktop</a></li>-->
# </ul>
# </div>
# <div id="boxConteudo">
# <script async="" crossorigin="anonymous" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-1339485442487398"></script>
# <!-- TopNovo -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-1339485442487398" data-ad-slot="4911295808" style="display:inline-block;width:990px;height:60px"></ins>
# <script>
#     (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# <div id="menuSuperiorh">
# <ul>
# <li><a class="" href="/?cc=1484&amp;cn=ms-campo-grande"><i class="fa fas fa-paw"></i>Home</a></li>
# <li><a class="" href="/entrar.aspx"><i class="fa fa fa-camera"></i>Postar</a></li>
# <li><a class="atual" href="/animais.aspx?cc=1484&amp;cn=ms-campo-grande&amp;finalidade=Adocao"><i class="fa fa fa-heart"></i>Adoção</a></li>
# <li><a class="" href="/animais.aspx?cc=1484&amp;cn=ms-campo-grande&amp;finalidade=Procura-Perdido"><i class="fa fa fa-binoculars"></i>Perdido</a></li>
# <li><a class="" href="/animais.aspx?cc=1484&amp;cn=ms-campo-grande&amp;finalidade=Encontrado"><i class="fa fa fa-life-ring"></i>Encontrado</a></li>
# <li class="ultimo"><a href="/busca.aspx?cc=1484&amp;cn=ms-campo-grande"><i class="fa fa fa-search"></i>Busca</a></li>
# </ul>
# </div>
# <script src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-5abf8ca2d6ab4aaa" type="text/javascript"></script>
# <div class="tituloSetor procurar"><strong>Cidade</strong> atual</div>
# <table cellspacing="0" id="ContentPlaceHolder1_ContentPlaceHolder1_FormViewCidade">
# <tr>
# <td colspan="2">
# <div id="mostraCidade">MS - Campo Grande (<a href="Default_escolher.aspx" id="ContentPlaceHolder1_ContentPlaceHolder1_FormViewCidade_HyperLinkCidadeTrocar">trocar</a>)</div>
# <input id="ContentPlaceHolder1_ContentPlaceHolder1_FormViewCidade_HiddenFieldCidade" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$FormViewCidade$HiddenFieldCidade" type="hidden" value="MS - Campo Grande"/>
# </td>
# </tr>
# </table>
# <span class="tituloSetor adocao" id="ContentPlaceHolder1_ContentPlaceHolder1_LabelTitulo">Pets para <strong>Adoção</strong><div class="addthis_inline_share_toolbox_36fw"></div></span>
# <ul class="boxCurvaGrande" id="listaFiltraTipo">
# <li class="titulo">Filtrar por:</li>
# <li class="cao">
# <a href="animais.aspx?cc=1484&amp;cn=ms-campo-grande&amp;finalidade=Adocao&amp;porte=Medio&amp;tipo=Cao" id="ContentPlaceHolder1_ContentPlaceHolder1_HyperLinkFiltroCao">Cão</a></li>
# <li class="gato">
# <a href="animais.aspx?cc=1484&amp;cn=ms-campo-grande&amp;finalidade=Adocao&amp;porte=Medio&amp;tipo=Gato" id="ContentPlaceHolder1_ContentPlaceHolder1_HyperLinkFiltroGato">Gato</a></li>
# </ul>
# <input id="HiddenFieldQtde" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1
/>
# <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldLinkExterno_18" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl18$HiddenFieldLinkExterno" type="hidden"/>
# </div>
# <div class="listaAnimais" data-animal="186860" data-idanimal="30b03b2021e22d58d57">
# <a href="/ms-campo-grande/cao/encontrado/perdida-femea-medio/186860" id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HyperLinkAnimal_19">
# <span class="listaAnimaisImagem">
# <div class="listaAnimaisImagemConteudo">
# <img border="0" src="//adotar.com.br/painel/upload/2021-03/animais_imagem694635.jpg"/>
# </div>
# </span>
# <div class="listaAnimaisDados">
#                             Perdida <br/>Femea / Médio<br/>
# </div>
# </a>
# <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldCod_19" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl19$HiddenFieldCod" type="hidden" value="30b03b2021e22d58d57"/>
# <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldLinkExterno_19" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl19$HiddenFieldLinkExterno" type="hidden"/>
# </div>
# <div id="outras-cidades"></div>
# <div class="paragrafo mt-10 mb-10">
# <!-- AnimaisNovoCentro -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-1339485442487398" data-ad-format="auto" data-ad-slot="7712062420" data-full-width-responsive="true" style="display: block"></ins>
# <script>
#                 (adsbygoogle = window.adsbygoogle || []).push({});
#             </script>
# </div>
# <div class="boxFinal" data-ultimoid="" id="box-final" style="text-align: center;">
# <a class="pegaMaisAnimais" href="javascript:selecionaMaisDesce(this);">Ver mais animais</a> | <a class="botaoFinalMudaCidade" href="/Default_escolher.aspx">Trocar cidade</a>
# </div>
# </div>
# <a href="animais.aspx?cc=1484&amp;cn=ms-campo-grande&amp;finalidade=Adocao&amp;porte=Medio&amp;semfoto=1" id="ContentPlaceHolder1_ContentPlaceHolder1_HyperLinkFiltroSemFoto"><b><font color="Black">ver animais sem foto</font></b></a>
# </div>
# <div style="position: relative; margin: auto; padding: 10px; margin-top: 20px;">
# <!-- RodapeNovo -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-1339485442487398" data-ad-format="auto" data-ad-slot="7321836728" data-full-width-responsive="true" style="display: block"></ins>
# <script>
#                     (adsbygoogle = window.adsbygoogle || []).push({});
#                 </script>
# </div>
# </form>
# </div>
# <script src="/js/jquery-3.6.0.min.js"></script>
# <script crossorigin="anonymous" src="https://kit.fontawesome.com/fd253adfbf.js"></script>
# <script src="https://www.gstatic.com/firebasejs/9.0.2/firebase-app-compat.js"></script>
# <script src="https://www.gstatic.com/firebasejs/9.0.2/firebase-messaging-compat.js"></script>
# <script src="https://www.gstatic.com/firebasejs/9.0.2/firebase-analytics-compat.js"></script>
# <script>
#
#
#         // Your web app's Firebase configuration
#         var firebaseConfig = {
#             apiKey: "AIzaSyDTFxzxe2lrkLI6cDj3vFfcupmjWkpl7Bk",
#             authDomain: "procure-1-amigo.firebaseapp.com",
#             databaseURL: "https://procure-1-amigo.firebaseio.com",
#             projectId: "procure-1-amigo",
#             storageBucket: "procure-1-amigo.appspot.com",
#             messagingSenderId: "999121279276",
#             appId: "1:999121279276:web:3f1782e6435fbd2961f489",
#             measurementId: "G-2E8HWL7RW0"
#         };
#         // Initialize Firebase
#         firebase.initializeApp(firebaseConfig);
#         firebase.analytics();
#
#     </script>
# <script src="/js/basicos.js"></script>
# <script type="text/javascript">
#         var vazio = false;
#         var ID = "";
#         var animais = "";
#         var trabalhando = false;
#
#         var cidade = getParameterByName('cc');
#         if (cidade == null || cidade == "")
#             cidade = "5214";
#
#         var querys = "cc=" + cidade;
#         if (getParameterByName('tipo') != null || getParameterByName('tipo') == "")
#             querys += "&tipo=" + getParameterByName('tipo');
#
#         if (getParameterByName('sexo') != null || getParameterByName('sexo') == "")
#             querys += "&sexo=" + getParameterByName('sexo');
#
#         if (getParameterByName('porte') != null || getParameterByName('porte') == "")
#             querys += "&porte=" + getParameterByName('porte');
#
#         if (getParameterByName('idade') != null || getParameterByName('idade') == "")
#             querys += "&idade=" + getParameterByName('idade');
#
#         if (getParameterByName('finalidade') != null || getParameterByName('finalidade') == "")
#             querys += "&finalidade=" + getParameterByName('finalidade');
#
#         if (getParameterByName('nome') != null || getParameterByName('nome') == "")
#             querys += "&nome=" + getParameterByName('nome');
#
#         if (getParameterByName('semfoto') != null || getParameterByName('semfoto') == "")
#             querys += "&semfoto=" + getParameterByName('semfoto');
#
#
#
#         function pegaID() {
#             $(".listaAnimais").each(function (index) {
#                 ID = $(this).data('idanimal');
#
#                 animais = animais + "-" + $(this).data('animal');
#             });
#         }
#
#         pegaID();
#
#
#         function selecionaMais() {
#
#             if (ID && !trabalhando) {
#                 $(".boxFinal").show('');
#                 $(".boxFinal").html('&nbsp;Buscando mais animais <i class="fa fa-circle-o-notch fa-spin"></i>.');
#
#                 var pagina = '/animais_jquery.aspx';
#
#                 if (vazio)
#                     pagina = '/animais_proximos.aspx';
#
#                 trabalhando = true;
#
#                 //console.log(querys);
#
#                 //data: querys + '&lastmsg=' + ID + '&animais=' + animais,
#                 $.ajax({
#                     type: "GET",
#                     url: pagina,
#                     data: querys + '&lastmsg=' + ID,
#                     cache: false,
#                     success: function (html) {
#                         $("div#updates").append(html.substring(html.indexOf('table') - 5).replace("</form>", ""));
#                         //$(".boxFinal").html('&nbsp;Veja mais animais <i class="fa fa-arrow-down" aria-hidden="true"></i>');
#                         //$(".boxFinal").hide();
#
#                         if (pagina == '/animais_proximos.aspx') {
#                             $(".boxFinal").html('&nbsp;Animais de outra cidade <i class="fa fa-arrow-down" aria-hidden="true"></i>');
#                             $(".boxFinal").show();
#                         }
#                         else
#                             $('.boxFinal').not(':last').remove();
#
#
#
#                         pegaID();
#                         trabalhando = false;
#
#                         //str.includes("wodrld")
#
#                         if (!html.includes("listaAnimaisDados")) {
#                             vazio = true;
#                             selecionaMais();
#                         }
#                     }
#                 });
#
#
#             }
#             else {
#                 $(".morebox").html('');
#             }
#
#             return false;
#         };
#
#
#         $(window).scroll(function () {
#             if (document.body.scrollHeight - $(this).scrollTop() - 2000 <= $(this).height()) {
#                 selecionaMais();
#             }
#         });
#
#         function selecionaMaisDesce(sender) {
#             selecionaMais();
#
#             $('html, body').animate({
#                 scrollTop: $("#" + sender).offset().top
#             }, 1000);
#         }
#
#
#
#
#
#
#
#         $(document).ready(function () {
#             var qtdeAnimais = parseFloat($("#HiddenFieldQtde").val());
#
#             if (qtdeAnimais < 20) {
#                 $(".boxFinal").show('');
#
#
#                 vazio = true;
#                 $(".boxFinal").html('&nbsp;Buscando animais próximos <i class="fa fa-circle-o-notch fa-spin"></i>.');
#
#                 $.ajax({
#                     type: "GET",
#                     url: "/animais_proximos.aspx",
#                     data: querys + '&animais=' + animais,
#                     cache: false,
#                     success: function (html) {
#                         $("#outras-cidades").append(html.substring(html.indexOf('table') - 5).replace("</form>", ""));
#                         $("#achou-nenhum").text('');
#                         $(".boxFinal").html('Animais próximos <i class="fa fa-arrow-down" aria-hidden="true"></i>');
#
#                         pegaID();
#                     }
#                 });
#             }
#
#         });
#
#
#         function getParameterByName(name, url) {
#             if (!url) url = window.location.href;
#             name = name.replace(/[\[\]]/g, '\\$&');
#             var regex = new RegExp('[?&]' + name + '(=([^&#]*)|&|#|$)'),
#                 results = regex.exec(url);
#             if (!results) return null;
#             if (!results[2]) return '';
#             return decodeURIComponent(results[2].replace(/\+/g, ' '));
#         }
#     </script>
# <div style="height: 30px;"></div>
# <div id="menuInferior">
# <ul>
# <li><a class="" href="/?cc=1484&amp;cn=ms-campo-grande"><i class="fa fas fa-paw"></i>Home</a></li>
# <li><a class="" href="/entrar.aspx"><i class="fa fa fa-camera"></i>Postar</a></li>
# <li><a class="atual" href="/animais.aspx?cc=1484&amp;cn=ms-campo-grande&amp;finalidade=Adocao"><i class="fa fa fa-heart"></i>Adoção</a></li>
# <li><a class="" href="/animais.aspx?cc=1484&amp;cn=ms-campo-grande&amp;finalidade=Procura-Perdido"><i class="fa fa fa-binoculars"></i>Perdido</a></li>
# <li><a class="" href="/animais.aspx?cc=1484&amp;cn=ms-campo-grande&amp;finalidade=Encontrado"><i class="fa fa fa-life-ring"></i>Encontrado</a></li>
# <li class="ultimo"><a href="/busca.aspx?cc=1484&amp;cn=ms-campo-grande"><i class="fa fa fa-search"></i>Busca</a></li>
# </ul>
# </div>
# <div id="avisa-cookie" style="display: none;">
#         Ao usar esse site você concorda com o uso de cookies e nossa política de privacidade.
#         <div class="botao">
#             Concordo
#         </div>
# </div>
# <script>
# </script>
# <script>
#
#         (function (i, s, o, g, r, a, m) {
#             i['GoogleAnalyticsObject'] = r; i[r] = i[r] || function () {
#                 (i[r].q = i[r].q || []).push(arguments)
#             }, i[r].l = 1 * new Date(); a = s.createElement(o),
#                 m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m)
#         })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#
#         ga('create', 'UA-24858037-2', 'auto');
#         ga('send', 'pageview');
#
#     </script>
# <script async="" crossorigin="anonymous" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-1339485442487398"></script>
# </body>
# </html>

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="pt-br">
#  <head>
#   <meta content="424936937573966" property="fb:app_id"/>
#   <meta content="website" property="og:type"/>
#   <meta content="pt-br" http-equiv="content-language"/>
#   <meta content="initial-scale=1.0" name="viewport"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    Cachorros para adoção em MS - Campo Grande - Procure 1 Amigo
#   </title>
#   <meta content="Cachorros para adoção em MS - Campo Grande - Procure 1 Amigo" name="title"/>
#   <meta content="Veja Cachorros para adoção em MS - Campo Grande - Procure 1 Amigo - cachorros e gatos de ONGs de proteção animal do Brasil - Adoção, doação e procura de cães e gatos" name="description"/>
#   <meta content="Cachorros para adoção em MS - Campo Grande - Procure 1 Amigo" name="keywords"/>
#   <meta content="Cachorros para adoção em MS - Campo Grande - Procure 1 Amigo" name="og:title" property="og:title"/>
#   <meta content="Veja Cachorros para adoção em MS - Campo Grande - Procure 1 Amigo - cachorros e gatos de ONGs de proteção animal do Brasil - Adoção, doação e procura de cães e gatos" name="og:description" property="og:description"/>
#   <meta content="https://adotar.com.br/imagens/amigos-cao-e-gato-dfaff.jpg" name="og:image" property="og:image"/>
#   <meta content="https://adotar.com.br/animais.aspx?cc=1484&amp;cn=ms-campo-grande&amp;finalidade=Adocao&amp;tipo=Cao&amp;porte=Medio" name="og:url" property="og:url"/>
#   <meta content="Procure 1 Amigo" name="og:site_name" property="og:site_name"/>
#   <meta content="424936937573966" name="fb:app_id" property="fb:app_id"/>
#   <meta content="website" name="og:type" property="og:type"/>
#   <meta content="@procure1amigo" name="twitter:site"/>
#   <meta content="Cachorros para adoção em MS - Campo Grande - Procure 1 Amigo" name="twitter:title"/>
#   <meta content="Veja Cachorros para adoção em MS - Campo Grande - Procure 1 Amigo - cachorros e gatos de ONGs de proteção animal do Brasil - Adoção, doação e procura de cães e gatos" name="twitter:description"/>
#   <meta content="https://adotar.com.br/imagens/amigos-cao-e-gato-dfaff.jpg" name="twitter:image"/>
#   <meta content="Procure1Amigo" name="apple-mobile-web-app-title"/>
#   <link href="//adotar.com.br/icones/apple-touch-icon-196x196-precomposed.png" rel="shortcut icon" sizes="196x196"/>
#   <link href="//adotar.com.br/icones/apple-touch-icon-152x152-precomposed.png" rel="apple-touch-icon-precomposed" sizes="152x152"/>
#   <link href="//adotar.com.br/icones/apple-touch-icon-144x144-precomposed.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>
#   <link href="//adotar.com.br/icones/apple-touch-icon-120x120-precomposed.png" rel="apple-touch-icon-precomposed" sizes="120x120"/>
#   <link href="//adotar.com.br/icones/apple-touch-icon-114x114-precomposed.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>
#   <link href="//adotar.com.br/icones/apple-touch-icon-76x76-precomposed.png" rel="apple-touch-icon-precomposed" sizes="76x76"/>
#   <link href="//adotar.com.br/icones/apple-touch-icon-72x72-precomposed.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>
#   <link href="//adotar.com.br/icones/apple-touch-icon-60x60-precomposed.png" rel="apple-touch-icon-precomposed" sizes="60x60"/>
#   <link href="//adotar.com.br/icones/apple-touch-icon-57x57-precomposed.png" rel="apple-touch-icon-precomposed" sizes="57x57"/>
#   <link href="//adotar.com.br/icones/apple-touch-icon-60x60-precomposed.png" rel="apple-touch-icon-precomposed"/>
#   <link href="//adotar.com.br/icones/apple-touch-icon-16x16-precomposed.png" rel="shortcut icon" sizes="16x16"/>
#   <link href="//adotar.com.br/icones/apple-touch-icon-76x76-precomposed.png" rel="apple-touch-icon" sizes="76x76"/>
#   <link href="//adotar.com.br/icones/apple-touch-icon-60x60-precomposed.png" rel="apple-touch-icon" sizes="60x60"/>
#   <link href="//adotar.com.br/icones/apple-touch-icon-60x60-precomposed.png" rel="apple-touch-icon"/>
#   <link href="//adotar.com.br/icones/iphoneSplashScreen.png" media="(device-width: 320px)" rel="apple-touch-startup-image"/>
#   <link href="//adotar.com.br/icones/iphone4SplashScreen.png" media="(device-width: 320px) and (-webkit-device-pixel-ratio: 2)" rel="apple-touch-startup-image"/>
#   <link href="//adotar.com.br/icones/iphone5SplashScreen.png" media="(device-height: 568px)" rel="apple-touch-startup-image"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="yes" name="mobile-web-app-capable"/>
#   <meta content="black" name="apple-mobile-web-app-status-bar-style"/>
#   <link href="//adotar.com.br/favico.ico" rel="icon" type="image/x-icon"/>
#   <link href="//adotar.com.br/favico.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link as="style" href="/css/geral.css" rel="preload"/>
#   <link href="/css/geral.css" rel="stylesheet"/>
#   <script type="text/javascript">
#    var endereco = window.location.href;
#         var veioModal = false;
#         if (endereco != null && endereco.toLowerCase().includes("modal=1")) {
#             //console.log("veio modal");
#             veioModal = true;
#         }
#         else {
#
#             var googletag = googletag || {};
#             googletag.cmd = googletag.cmd || [];
#             (function () {
#                 var gads = document.createElement('script');
#                 gads.async = true;
#                 gads.type = 'text/javascript';
#                 var useSSL = 'https:' == document.location.protocol;
#                 gads.src = (useSSL ? 'https:' : 'http:') +
#                     '//www.googletagservices.com/tag/js/gpt.js';
#                 var node = document.getElementsByTagName('script')[0];
#                 node.parentNode.insertBefore(gads, node);
#             })();
#
#
#
#             googletag.cmd.push(function () {
#                 googletag.defineSlot('/75766867/Movel-Top', [320, 50], 'div-gpt-ad-1431185685094-0').addService(googletag.pubads());
#                 googletag.defineSlot('/75766867/MovelRodape', [300, 250], 'div-gpt-ad-1431185685094-1').addService(googletag.pubads());
#                 googletag.pubads().enableSingleRequest();
#                 googletag.enableServices();
#             });
#
#         }
#   </script>
#   <script defer="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#   </script>
#   <link href="/manifest.json" rel="manifest"/>
#   <link href="https://adotar.com.br/animais.aspx?cc=1484&amp;cn=ms-campo-grande&amp;finalidade=Adocao&amp;tipo=Cao&amp;porte=Medio" rel="canonical"/>
#  </head>
#  <body id="Body">
#   <div class="max-centraliza">
#    <form action="./animais.aspx?cc=1484&amp;cn=ms-campo-grande&amp;finalidade=Adocao&amp;tipo=Cao&amp;porte=Medio" id="form1" method="post">
#     <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="..."/>
#     <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="736D0F40"/>
#     <input id="__EVENTVALIDATION" name="__EVENTVALIDATION" type="hidden" value="..."/>
#     <div id="boxTopo">
#      <div class="max-centraliza">
#       <img alt="Menu" border="0" id="botaoMenu" src="/imagens/menu_botao.png"/>
#       <a href="/" id="HyperLinkLogo" title="Procure 1 Amigo - Animais para Adoção, doação e procura de cachorros e gatos">
#        <img alt="Procure 1 Amigo - Animais para Adoção, doação e procura de cachorros e gatos" border="0" id="logo-procure-master" src="/imagens/logo.png"/>
#       </a>
#       <div id="boxTopoDireita">
#        <span id="LabelPaginaAtual">
#         <i class="fa fa-heart">
#         </i>
#         <u>
#          Adoção
#         </u>
#        </span>
#       </div>
#       <!--<a title="Ajuda para adotar, doar e procurar" href='javascript:;' id="quero-ajuda"><i class="fa fa-question-circle" aria-hidden="true"></i></a>-->
#      </div>
#     </div>
#     <div id="menuPrincipal">
#      <ul>
#       <li>
#        <a href="/?cc=1484&amp;cn=ms-campo-grande&amp;">
#         Início
#        </a>
#       </li>
#       <!--<li><a href="painel">Cadastrar animal</a></li>-->
#       <li>
#        <a href="/animais.aspx?cc=1484&amp;cn=ms-campo-grande&amp;finalidade=Adocao">
#         Animais para adoção
#        </a>
#       </li>
#       <li>
#        <a href="/animais.aspx?cc=1484&amp;cn=ms-campo-grande&amp;finalidade=Procura-Perdido">
#         Animais perdidos
#        </a>
#       </li>
#       <li>
#        <a href="/animais.aspx?cc=1484&amp;cn=ms-campo-grande&amp;finalidade=Encontrado">
#         Animais encontrados
#        </a>
#       </li>
#       <li>
#        <a href="/busca.aspx?cc=1484&amp;cn=ms-campo-grande">
#         Busca detalhada
#        </a>
#       </li>
#       <li>
#        <a href="/eventos.aspx">
#         Eventos
#        </a>
#       </li>
#       <li>
#        <a href="https://loja.procure1amigo.com.br/" rel="noopener" target="_blank">
#         Loja
#        </a>
#       </li>
#       <li>
#        <a href="/blog.aspx">
#         Blog
#        </a>
#       </li>
#       <li>
#        <a href="/fale_conosco.aspx">
#         Contato
#        </a>
#       </li>
#       <li>
#        <a href="/entrar.aspx">
#         Cadastrar animal
#        </a>
#       </li>
#       <li>
#        <a href="/cadastro_finaliza.aspx">
#         Ajude-nos
#        </a>
#       </li>
#       <li>
#        <a href="/quem_somos.aspx">
#         Quem Somos
#        </a>
#       </li>
#       <!--<li><a href='//adotar.com.br/?fixa=1'>Site desktop</a></li>-->
#      </ul>
#     </div>
#     <div id="boxConteudo">
#      <script async="" crossorigin="anonymous" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-1339485442487398">
#      </script>
#      <!-- TopNovo -->
#      <ins class="adsbygoogle" data-ad-client="ca-pub-1339485442487398" data-ad-slot="4911295808" style="display:inline-block;width:990px;height:60px">
#      </ins>
#      <script>
#       (adsbygoogle = window.adsbygoogle || []).push({});
#      </script>
#      <div id="menuSuperiorh">
#       <ul>
#        <li>
#         <a class="" href="/?cc=1484&amp;cn=ms-campo-grande">
#          <i class="fa fas fa-paw">
#          </i>
#          Home
#         </a>
#        </li>
#        <li>
#         <a class="" href="/entrar.aspx">
#          <i class="fa fa fa-camera">
#          </i>
#          Postar
#         </a>
#        </li>
#        <li>
#         <a class="atual" href="/animais.aspx?cc=1484&amp;cn=ms-campo-grande&amp;finalidade=Adocao">
#          <i class="fa fa fa-heart">
#          </i>
#          Adoção
#         </a>
#        </li>
#        <li>
#         <a class="" href="/animais.aspx?cc=1484&amp;cn=ms-campo-grande&amp;finalidade=Procura-Perdido">
#          <i class="fa fa fa-binoculars">
#          </i>
#          Perdido
#         </a>
#        </li>
#        <li>
#         <a class="" href="/animais.aspx?cc=1484&amp;cn=ms-campo-grande&amp;finalidade=Encontrado">
#          <i class="fa fa fa-life-ring">
#          </i>
#          Encontrado
#         </a>
#        </li>
#        <li class="ultimo">
#         <a href="/busca.aspx?cc=1484&amp;cn=ms-campo-grande">
#          <i class="fa fa fa-search">
#          </i>
#          Busca
#         </a>
#        </li>
#       </ul>
#      </div>
#      <script src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-5abf8ca2d6ab4aaa" type="text/javascript">
#      </script>
#      <div class="tituloSetor procurar">
#       <strong>
#        Cidade
#       </strong>
#       atual
#      </div>
#      <table cellspacing="0" id="ContentPlaceHolder1_ContentPlaceHolder1_FormViewCidade">
#       <tr>
#        <td colspan="2">
#         <div id="mostraCidade">
#          MS - Campo Grande (
#          <a href="Default_escolher.aspx" id="ContentPlaceHolder1_ContentPlaceHolder1_FormViewCidade_HyperLinkCidadeTrocar">
#           trocar
#          </a>
#          )
#         </div>
#         <input id="ContentPlaceHolder1_ContentPlaceHolder1_FormViewCidade_HiddenFieldCidade" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$FormViewCidade$HiddenFieldCidade" type="hidden" value="MS - Campo Grande"/>
#        </td>
#       </tr>
#      </table>
#      <span class="tituloSetor adocao" id="ContentPlaceHolder1_ContentPlaceHolder1_LabelTitulo">
#       Pets para
#       <strong>
#        Adoção
#       </strong>
#       <div class="addthis_inline_share_toolbox_36fw">
#       </div>
#      </span>
#      <ul class="boxCurvaGrande" id="listaFiltraTipo">
#       <li class="titulo">
#        Filtrar por:
#       </li>
#       <li class="cao">
#        <a href="animais.aspx?cc=1484&amp;cn=ms-campo-grande&amp;finalidade=Adocao&amp;porte=Medio&amp;tipo=Cao" id="ContentPlaceHolder1_ContentPlaceHolder1_HyperLinkFiltroCao">
#         Cão
#        </a>
#       </li>
#       <li class="gato">
#        <a href="animais.aspx?cc=1484&amp;cn=ms-campo-grande&amp;finalidade=Adocao&amp;porte=Medio&amp;tipo=Gato" id="ContentPlaceHolder1_ContentPlaceHolder1_HyperLinkFiltroGato">
#         Gato
#        </a>
#       </li>
#      </ul>
#      <input id="HiddenFieldQtde" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$HiddenFieldQtde" type="hidden" value="20"/>
#      <div class="timeline" id="updates">
#       <div class="listaAnimais" data-animal="208783" data-idanimal="27b12b2021e10d08d57">
#        <a href="/ms-campo-grande/cao/adocao/biscoito-e-nemo-macho-medio/208783" id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HyperLinkAnimal_0">
#         <span class="listaAnimaisImagem">
#          <div class="listaAnimaisImagemConteudo">
#           <img border="0" src="//adotar.com.br/painel/upload/2021-12/animais_imagem792916.jpg"/>
#          </div>
#         </span>
#         <div class="listaAnimaisDados">
#          Biscoito e Nemo
#          <span class="novo">
#           Novo
#          </span>
#          <br/>
#          Macho / Médio
#          <br/>
#          2 a 6 meses
#         </div>
#        </a>
#        <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldCod_0" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl00$HiddenFieldCod" type="hidden" value="27b12b2021e10d08d57"/>
#        <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldLinkExterno_0" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl00$HiddenFieldLinkExterno" type="hidden"/>
#       </div>
#       <div class="listaAnimais" data-animal="208461" data-idanimal="20b12b2021e18d08d51">
#        <a href="/ms-campo-grande/cao/adocao/kira-fox-paulistino-femea-medio/208461" id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HyperLinkAnimal_1">
#         <span class="listaAnimaisImagem">
#          <div class="listaAnimaisImagemConteudo">
#           <img border="0" src="//adotar.com.br/painel/upload/2021-12/animais_imagem792086.jpg"/>
#          </div>
#         </span>
#         <div class="listaAnimaisDados">
#          Kira
#          <span class="novo">
#           Novo
#          </span>
#          <br/>
#          Femea / Médio
#          <br/>
#          2 anos
#         </div>
#        </a>
#        <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldCod_1" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl01$HiddenFieldCod" type="hidden" value="20b12b2021e18d08d51"/>
#        <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldLinkExterno_1" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl01$HiddenFieldLinkExterno" type="hidden"/>
#       </div>
#       <div class="listaAnimais" data-animal="207231" data-idanimal="01b12b2021e16d59d40">
#        <a href="/ms-campo-grande/cao/adocao/chico-vira-lata-macho-medio/207231" id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HyperLinkAnimal_2">
#         <span class="listaAnimaisImagem">
#          <div class="listaAnimaisImagemConteudo">
#           <img border="0" src="//adotar.com.br/painel/upload/2021-12/animais_imagem784680.jpg"/>
#          </div>
#         </span>
#         <div class="listaAnimaisDados">
#          CHICO
#          <br/>
#          Macho / Médio
#          <br/>
#          7 a 11 meses
#         </div>
#        </a>
#        <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldCod_2" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl02$HiddenFieldCod" type="hidden" value="01b12b2021e16d59d40"/>
#        <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldLinkExterno_2" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl02$HiddenFieldLinkExterno" type="hidden"/>
#       </div>
#       <div class="listaAnimais" data-animal="207062" data-idanimal="29b11b2021e12d20d24">
#        <a href="/ms-campo-grande/cao/adocao/jade-srd-viralata-femea-medio/207062" id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HyperLinkAnimal_3">
#         <span class="listaAnimaisImagem">
#          <div class="listaAnimaisImagemConteudo">
#           <img border="0" src="//adotar.com.br/painel/upload/2021-11/animais_imagem783861.jpg"/>
#          </div>
#         </span>
#         <div class="listaAnimaisDados">
#          jade
#          <br/>
#          Femea / Médio
#          <br/>
#          2 a 6 meses
#         </div>
#        </a>
#        <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldCod_3" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl03$HiddenFieldCod" type="hidden" value="29b11b2021e12d20d24"/>
#        <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldLinkExterno_3" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl03$HiddenFieldLinkExterno" type="hidden"/>
#       </div>
#       <div class="listaAnimais" data-animal="207054" data-idanimal="29b11b2021e11d28d37">
#        <a href="/ms-campo-grande/cao/adocao/kira-fox-paulistino-femea-medio/207054" id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HyperLinkAnimal_4">
#         <span class="listaAnimaisImagem">
#          <div class="listaAnimaisImagemConteudo">
#           <img border="0" src="//adotar.com.br/painel/upload/2021-11/animais_imagem783822.jpg"/>
#          </div>
#         </span>
#         <div class="listaAnimaisDados">
#          Kira
#          <br/>
#          Femea / Médio
#          <br/>
#          2 anos
#         </div>
#        </a>
#        <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldCod_4" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl04$HiddenFieldCod" type="hidden" value="29b11b2021e11d28d37"/>
#        <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldLinkExterno_4" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl04$HiddenFieldLinkExterno" type="hidden"/>
#       </div>
#       <div class="listaAnimais" data-animal="207031" data-idanimal="28b11b2021e21d04d51">
#        <a href="/ms-campo-grande/cao/adocao/a-escolher-srd-macho-femea-medio/207031" id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HyperLinkAnimal_5">
#         <span class="listaAnimaisImagem">
#          <div class="listaAnimaisImagemConteudo">
#           <img border="0" src="//adotar.com.br/painel/upload/2021-11/animais_imagem783747.jpg"/>
#          </div>
#         </span>
#         <div class="listaAnimaisDados">
#          A escolher
#          <br/>
#          Ambos / Médio
#          <br/>
#          Abaixo de 2 meses
#         </div>
#        </a>
#        <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldCod_5" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl05$HiddenFieldCod" type="hidden" value="28b11b2021e21d04d51"/>
#        <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldLinkExterno_5" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl05$HiddenFieldLinkExterno" type="hidden"/>
#       </div>
#       <div class="listaAnimais" data-animal="206173" data-idanimal="16b11b2021e18d44d04">
#        <a href="/ms-campo-grande/cao/adocao/pipoca-neguinho-e-r-vira-lata-macho-medio/206173" id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HyperLinkAnimal_6">
#         <span class="listaAnimaisImagem">
#          <div class="listaAnimaisImagemConteudo">
#           <img border="0" src="//adotar.com.br/painel/upload/2021-11/animais_imagem779552.jpg"/>
#          </div>
#         </span>
#         <div class="listaAnimaisDados">
#          Pipoca, neguinho e r
#          <br/>
#          Macho / Médio
#          <br/>
#          Abaixo de 2 meses
#         </div>
#        </a>
#        <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldCod_6" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl06$HiddenFieldCod" type="hidden" value="16b11b2021e18d44d04"/>
#        <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldLinkExterno_6" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl06$HiddenFieldLinkExterno" type="hidden"/>
#       </div>
#       <div class="listaAnimais" data-animal="206048" data-idanimal="15b11b2021e16d44d51">
#        <a href="/ms-campo-grande/cao/adocao/thor-chow-chow-macho-medio/206048" id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HyperLinkAnimal_7">
#         <span class="listaAnimaisImagem">
#          <div class="listaAnimaisImagemConteudo">
#           <img border="0" src="//adotar.com.br/painel/upload/2021-11/animais_imagem778806.jpg"/>
#          </div>
#         </span>
#         <div class="listaAnimaisDados">
#          Thor
#          <br/>
#          Macho / Médio
#          <br/>
#          1 ano
#         </div>
#        </a>
#        <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldCod_7" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl07$HiddenFieldCod" type="hidden" value="15b11b2021e16d44d51"/>
#        <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldLinkExterno_7" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl07$HiddenFieldLinkExterno" type="hidden"/>
#       </div>
#       <div class="listaAnimais" data-animal="205886" data-idanimal="12b11b2021e21d27d30">
#        <a href="/ms-campo-grande/cao/adocao/jack-aurora-bombom-b-srd-macho-femea-medio/205886" id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HyperLinkAnimal_8">
#         <span class="listaAnimaisImagem">
#          <div class="listaAnimaisImagemConteudo">
#           <img border="0" src="//adotar.com.br/painel/upload/2021-11/animais_imagem777753.jpg"/>
#          </div>
#         </span>
#         <div class="listaAnimaisDados">
#          Jack aurora bombom b
#          <br/>
#          Ambos / Médio
#          <br/>
#          2 a 6 meses
#         </div>
#        </a>
#        <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldCod_8" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl08$HiddenFieldCod" type="hidden" value="12b11b2021e21d27d30"/>
#        <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldLinkExterno_8" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl08$HiddenFieldLinkExterno" type="hidden"/>
#       </div>
#       <div class="listaAnimais" data-animal="202607" data-idanimal="28b09b2021e19d37d28">
#        <a href="/ms-campo-grande/cao/adocao/piter-park-sem-raca-definida-macho-medio/202607" id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HyperLinkAnimal_9">
#         <span class="listaAnimaisImagem">
#          <div class="listaAnimaisImagemConteudo">
#           <img border="0" src="//adotar.com.br/painel/upload/2021-09/animais_imagem761568.jpg"/>
#          </div>
#         </span>
#         <div class="listaAnimaisDados">
#          Piter park
#          <br/>
#          Macho / Médio
#          <br/>
#          1 ano
#         </div>
#        </a>
#        <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldCod_9" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl09$HiddenFieldCod" type="hidden" value="28b09b2021e19d37d28"/>
#        <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldLinkExterno_9" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl09$HiddenFieldLinkExterno" type="hidden"/>
#       </div>
#       <div class="listaAnimais" data-animal="201456" data-idanimal="10b09b2021e21d12d17">
#        <a href="/ms-campo-grande/cao/adocao/maya-vira-lata-femea-medio/201456" id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HyperLinkAnimal_10">
#         <span class="listaAnimaisImagem">
#          <div class="listaAnimaisImagemConteudo">
#           <img border="0" src="//adotar.com.br/painel/upload/2021-09/animais_imagem755919.jpg"/>
#          </div>
#         </span>
#         <div class="listaAnimaisDados">
#          Maya
#          <br/>
#          Femea / Médio
#          <br/>
#          1 ano
#         </div>
#        </a>
#        <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldCod_10" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl10$HiddenFieldCod" type="hidden" value="10b09b2021e21d12d17"/>
#        <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldLinkExterno_10" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl10$HiddenFieldLinkExterno" type="hidden"/>
#       </div>
#       <div class="listaAnimais" data-animal="201195" data-idanimal="06b09b2021e23d55d47">
#        <a href="/ms-campo-grande/cao/adocao/pingo-poodle-macho-medio/201195" id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HyperLinkAnimal_11">
#         <span class="listaAnimaisImagem">
#          <div class="listaAnimaisImagemConteudo">
#           <img border="0" src="//adotar.com.br/painel/upload/2021-09/animais_imagem754477.jpg"/>
#          </div>
#         </span>
#         <div class="listaAnimaisDados">
#          Pingo
#          <br/>
#          Macho / Médio
#          <br/>
#          2 a 6 meses
#         </div>
#        </a>
#        <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldCod_11" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl11$HiddenFieldCod" type="hidden" value="06b09b2021e23d55d47"/>
#        <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldLinkExterno_11" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl11$HiddenFieldLinkExterno" type="hidden"/>
#       </div>
#       <div class="listaAnimais" data-animal="200623" data-idanimal="30b08b2021e09d48d58">
#        <a href="/ms-campo-grande/cao/adocao/nemo-vira-lata-macho-medio/200623" id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HyperLinkAnimal_12">
#         <span class="listaAnimaisImagem">
#          <div class="listaAnimaisImagemConteudo">
#           <img border="0" src="//adotar.com.br/painel/upload/2021-08/animais_imagem751631.jpg"/>
#          </div>
#         </span>
#         <div class="listaAnimaisDados">
#          Nemo
#          <br/>
#          Macho / Médio
#          <br/>
#          1 ano
#         </div>
#        </a>
#        <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldCod_12" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl12$HiddenFieldCod" type="hidden" value="30b08b2021e09d48d58"/>
#        <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldLinkExterno_12" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl12$HiddenFieldLinkExterno" type="hidden"/>
#       </div>
#       <div class="listaAnimais" data-animal="199759" data-idanimal="17b08b2021e15d39d01">
#        <a href="/ms-campo-grande/cao/adocao/sem-nome-srd-viralata-macho-femea-medio/199759" id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HyperLinkAnimal_13">
#         <span class="listaAnimaisImagem">
#          <div class="listaAnimaisImagemConteudo">
#           <img border="0" src="//adotar.com.br/painel/upload/2021-08/animais_imagem747606.jpg"/>
#          </div>
#         </span>
#         <div class="listaAnimaisDados">
#          sem nome
#          <br/>
#          Ambos / Médio
#          <br/>
#          Abaixo de 2 meses
#         </div>
#        </a>
#        <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldCod_13" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl13$HiddenFieldCod" type="hidden" value="17b08b2021e15d39d01"/>
#        <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldLinkExterno_13" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl13$HiddenFieldLinkExterno" type="hidden"/>
#       </div>
#       <div class="listaAnimais" data-animal="196410" data-idanimal="11b07b2021e16d52d28">
#        <a href="/ms-campo-grande/cao/adocao/sem-nome-sem-raca-macho-femea-medio/196410" id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HyperLinkAnimal_14">
#         <span class="listaAnimaisImagem">
#          <div class="listaAnimaisImagemConteudo">
#           <img border="0" src="//adotar.com.br/painel/upload/2021-07/animais_imagem736164.jpg"/>
#          </div>
#         </span>
#         <div class="listaAnimaisDados">
#          Sem nome
#          <br/>
#          Ambos / Médio
#          <br/>
#          2 a 6 meses
#         </div>
#        </a>
#        <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldCod_14" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl14$HiddenFieldCod" type="hidden" value="11b07b2021e16d52d28"/>
#        <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldLinkExterno_14" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl14$HiddenFieldLinkExterno" type="hidden"/>
#       </div>
#       <div class="listaAnimais" data-animal="195305" data-idanimal="25b06b2021e19d58d16">
#        <a href="/ms-campo-grande/cao/encontrado/isa-femea-medio/195305" id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HyperLinkAnimal_15">
#         <span class="listaAnimaisImagem">
#          <div class="listaAnimaisImagemConteudo">
#           <img border="0" src="//adotar.com.br/painel/upload/2021-06/animais_imagem730348.jpg"/>
#          </div>
#         </span>
#         <div class="listaAnimaisDados">
#          Isa
#          <br/>
#          Femea / Médio
#          <br/>
#          7 a 11 meses
#         </div>
#        </a>
#        <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldCod_15" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl15$HiddenFieldCod" type="hidden" value="25b06b2021e19d58d16"/>
#        <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldLinkExterno_15" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl15$HiddenFieldLinkExterno" type="hidden"/>
#       </div>
#       <div class="listaAnimais" data-animal="194153" data-idanimal="11b06b2021e13d46d43">
#        <a href="/ms-campo-grande/cao/adocao/mike-e-fibe-vira-lata-macho-femea-medio/194153" id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HyperLinkAnimal_16">
#         <span class="listaAnimaisImagem">
#          <div class="listaAnimaisImagemConteudo">
#           <img border="0" src="//adotar.com.br/painel/upload/2021-06/animais_imagem724465.jpg"/>
#          </div>
#         </span>
#         <div class="listaAnimaisDados">
#          Mike e Fibe
#          <br/>
#          Ambos / Médio
#          <br/>
#          1 ano
#         </div>
#        </a>
#        <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldCod_16" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl16$HiddenFieldCod" type="hidden" value="11b06b2021e13d46d43"/>
#        <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldLinkExterno_16" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl16$HiddenFieldLinkExterno" type="hidden"/>
#       </div>
#       <div class="listaAnimais" data-animal="192694" data-idanimal="05b06b2021e16d44d34">
#        <a href="/ms-campo-grande/cao/adocao/kahli-nao-definida-femea-medio/192694" id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HyperLinkAnimal_17">
#         <span class="listaAnimaisImagem">
#          <div class="listaAnimaisImagemConteudo">
#           <img border="0" src="//adotar.com.br/painel/upload/2021-06/animais_imagem721613.jpg"/>
#          </div>
#         </span>
#         <div class="listaAnimaisDados">
#          Kahli
#          <br/>
#          Femea / Médio
#          <br/>
#          3 anos
#         </div>
#        </a>
#        <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldCod_17" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl17$HiddenFieldCod" type="hidden" value="05b06b2021e16d44d34"/>
#        <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldLinkExterno_17" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl17$HiddenFieldLinkExterno" type="hidden"/>
#       </div>
#       <div class="listaAnimais" data-animal="192361" data-idanimal="01b06b2021e17d52d26">
#        <a href="/ms-campo-grande/cao/adocao/luna-vira-lata-femea-medio/192361" id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HyperLinkAnimal_18">
#         <span class="listaAnimaisImagem">
#          <div class="listaAnimaisImagemConteudo">
#           <img border="0" src="//adotar.com.br/painel/upload/2021-06/animais_imagem720102.jpg"/>
#          </div>
#         </span>
#         <div class="listaAnimaisDados">
#          Luna
#          <br/>
#          Femea / Médio
#          <br/>
#          2 anos
#         </div>
#        </a>
#        <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldCod_18" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl18$HiddenFieldCod" type="hidden" value="01b06b2021e17d52d26"/>
#        <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldLinkExterno_18" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl18$HiddenFieldLinkExterno" type="hidden"/>
#       </div>
#       <div class="listaAnimais" data-animal="186860" data-idanimal="30b03b2021e22d58d57">
#        <a href="/ms-campo-grande/cao/encontrado/perdida-femea-medio/186860" id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HyperLinkAnimal_19">
#         <span class="listaAnimaisImagem">
#          <div class="listaAnimaisImagemConteudo">
#           <img border="0" src="//adotar.com.br/painel/upload/2021-03/animais_imagem694635.jpg"/>
#          </div>
#         </span>
#         <div class="listaAnimaisDados">
#          Perdida
#          <br/>
#          Femea / Médio
#          <br/>
#         </div>
#        </a>
#        <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldCod_19" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl19$HiddenFieldCod" type="hidden" value="30b03b2021e22d58d57"/>
#        <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldLinkExterno_19" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl19$HiddenFieldLinkExterno" type="hidden"/>
#       </div>
#       <div id="outras-cidades">
#       </div>
#       <div class="paragrafo mt-10 mb-10">
#        <!-- AnimaisNovoCentro -->
#        <ins class="adsbygoogle" data-ad-client="ca-pub-1339485442487398" data-ad-format="auto" data-ad-slot="7712062420" data-full-width-responsive="true" style="display: block">
#        </ins>
#        <script>
#         (adsbygoogle = window.adsbygoogle || []).push({});
#        </script>
#       </div>
#       <div class="boxFinal" data-ultimoid="" id="box-final" style="text-align: center;">
#        <a class="pegaMaisAnimais" href="javascript:selecionaMaisDesce(this);">
#         Ver mais animais
#        </a>
#        |
#        <a class="botaoFinalMudaCidade" href="/Default_escolher.aspx">
#         Trocar cidade
#        </a>
#       </div>
#      </div>
#      <a href="animais.aspx?cc=1484&amp;cn=ms-campo-grande&amp;finalidade=Adocao&amp;porte=Medio&amp;semfoto=1" id="ContentPlaceHolder1_ContentPlaceHolder1_HyperLinkFiltroSemFoto">
#       <b>
#        <font color="Black">
#         ver animais sem foto
#        </font>
#       </b>
#      </a>
#     </div>
#     <div style="position: relative; margin: auto; padding: 10px; margin-top: 20px;">
#      <!-- RodapeNovo -->
#      <ins class="adsbygoogle" data-ad-client="ca-pub-1339485442487398" data-ad-format="auto" data-ad-slot="7321836728" data-full-width-responsive="true" style="display: block">
#      </ins>
#      <script>
#       (adsbygoogle = window.adsbygoogle || []).push({});
#      </script>
#     </div>
#    </form>
#   </div>
#   <script src="/js/jquery-3.6.0.min.js">
#   </script>
#   <script crossorigin="anonymous" src="https://kit.fontawesome.com/fd253adfbf.js">
#   </script>
#   <script src="https://www.gstatic.com/firebasejs/9.0.2/firebase-app-compat.js">
#   </script>
#   <script src="https://www.gstatic.com/firebasejs/9.0.2/firebase-messaging-compat.js">
#   </script>
#   <script src="https://www.gstatic.com/firebasejs/9.0.2/firebase-analytics-compat.js">
#   </script>
#   <script>
#    // Your web app's Firebase configuration
#         var firebaseConfig = {
#             apiKey: "AIzaSyDTFxzxe2lrkLI6cDj3vFfcupmjWkpl7Bk",
#             authDomain: "procure-1-amigo.firebaseapp.com",
#             databaseURL: "https://procure-1-amigo.firebaseio.com",
#             projectId: "procure-1-amigo",
#             storageBucket: "procure-1-amigo.appspot.com",
#             messagingSenderId: "999121279276",
#             appId: "1:999121279276:web:3f1782e6435fbd2961f489",
#             measurementId: "G-2E8HWL7RW0"
#         };
#         // Initialize Firebase
#         firebase.initializeApp(firebaseConfig);
#         firebase.analytics();
#   </script>
#   <script src="/js/basicos.js">
#   </script>
#   <script type="text/javascript">
#    var vazio = false;
#         var ID = "";
#         var animais = "";
#         var trabalhando = false;
#
#         var cidade = getParameterByName('cc');
#         if (cidade == null || cidade == "")
#             cidade = "5214";
#
#         var querys = "cc=" + cidade;
#         if (getParameterByName('tipo') != null || getParameterByName('tipo') == "")
#             querys += "&tipo=" + getParameterByName('tipo');
#
#         if (getParameterByName('sexo') != null || getParameterByName('sexo') == "")
#             querys += "&sexo=" + getParameterByName('sexo');
#
#         if (getParameterByName('porte') != null || getParameterByName('porte') == "")
#             querys += "&porte=" + getParameterByName('porte');
#
#         if (getParameterByName('idade') != null || getParameterByName('idade') == "")
#             querys += "&idade=" + getParameterByName('idade');
#
#         if (getParameterByName('finalidade') != null || getParameterByName('finalidade') == "")
#             querys += "&finalidade=" + getParameterByName('finalidade');
#
#         if (getParameterByName('nome') != null || getParameterByName('nome') == "")
#             querys += "&nome=" + getParameterByName('nome');
#
#         if (getParameterByName('semfoto') != null || getParameterByName('semfoto') == "")
#             querys += "&semfoto=" + getParameterByName('semfoto');
#
#
#
#         function pegaID() {
#             $(".listaAnimais").each(function (index) {
#                 ID = $(this).data('idanimal');
#
#                 animais = animais + "-" + $(this).data('animal');
#             });
#         }
#
#         pegaID();
#
#
#         function selecionaMais() {
#
#             if (ID && !trabalhando) {
#                 $(".boxFinal").show('');
#                 $(".boxFinal").html('&nbsp;Buscando mais animais <i class="fa fa-circle-o-notch fa-spin"></i>.');
#
#                 var pagina = '/animais_jquery.aspx';
#
#                 if (vazio)
#                     pagina = '/animais_proximos.aspx';
#
#                 trabalhando = true;
#
#                 //console.log(querys);
#
#                 //data: querys + '&lastmsg=' + ID + '&animais=' + animais,
#                 $.ajax({
#                     type: "GET",
#                     url: pagina,
#                     data: querys + '&lastmsg=' + ID,
#                     cache: false,
#                     success: function (html) {
#                         $("div#updates").append(html.substring(html.indexOf('table') - 5).replace("</form>", ""));
#                         //$(".boxFinal").html('&nbsp;Veja mais animais <i class="fa fa-arrow-down" aria-hidden="true"></i>');
#                         //$(".boxFinal").hide();
#
#                         if (pagina == '/animais_proximos.aspx') {
#                             $(".boxFinal").html('&nbsp;Animais de outra cidade <i class="fa fa-arrow-down" aria-hidden="true"></i>');
#                             $(".boxFinal").show();
#                         }
#                         else
#                             $('.boxFinal').not(':last').remove();
#
#
#
#                         pegaID();
#                         trabalhando = false;
#
#                         //str.includes("wodrld")
#
#                         if (!html.includes("listaAnimaisDados")) {
#                             vazio = true;
#                             selecionaMais();
#                         }
#                     }
#                 });
#
#
#             }
#             else {
#                 $(".morebox").html('');
#             }
#
#             return false;
#         };
#
#
#         $(window).scroll(function () {
#             if (document.body.scrollHeight - $(this).scrollTop() - 2000 <= $(this).height()) {
#                 selecionaMais();
#             }
#         });
#
#         function selecionaMaisDesce(sender) {
#             selecionaMais();
#
#             $('html, body').animate({
#                 scrollTop: $("#" + sender).offset().top
#             }, 1000);
#         }
#
#
#
#
#
#
#
#         $(document).ready(function () {
#             var qtdeAnimais = parseFloat($("#HiddenFieldQtde").val());
#
#             if (qtdeAnimais < 20) {
#                 $(".boxFinal").show('');
#
#
#                 vazio = true;
#                 $(".boxFinal").html('&nbsp;Buscando animais próximos <i class="fa fa-circle-o-notch fa-spin"></i>.');
#
#                 $.ajax({
#                     type: "GET",
#                     url: "/animais_proximos.aspx",
#                     data: querys + '&animais=' + animais,
#                     cache: false,
#                     success: function (html) {
#                         $("#outras-cidades").append(html.substring(html.indexOf('table') - 5).replace("</form>", ""));
#                         $("#achou-nenhum").text('');
#                         $(".boxFinal").html('Animais próximos <i class="fa fa-arrow-down" aria-hidden="true"></i>');
#
#                         pegaID();
#                     }
#                 });
#             }
#
#         });
#
#
#         function getParameterByName(name, url) {
#             if (!url) url = window.location.href;
#             name = name.replace(/[\[\]]/g, '\\$&');
#             var regex = new RegExp('[?&]' + name + '(=([^&#]*)|&|#|$)'),
#                 results = regex.exec(url);
#             if (!results) return null;
#             if (!results[2]) return '';
#             return decodeURIComponent(results[2].replace(/\+/g, ' '));
#         }
#   </script>
#   <div style="height: 30px;">
#   </div>
#   <div id="menuInferior">
#    <ul>
#     <li>
#      <a class="" href="/?cc=1484&amp;cn=ms-campo-grande">
#       <i class="fa fas fa-paw">
#       </i>
#       Home
#      </a>
#     </li>
#     <li>
#      <a class="" href="/entrar.aspx">
#       <i class="fa fa fa-camera">
#       </i>
#       Postar
#      </a>
#     </li>
#     <li>
#      <a class="atual" href="/animais.aspx?cc=1484&amp;cn=ms-campo-grande&amp;finalidade=Adocao">
#       <i class="fa fa fa-heart">
#       </i>
#       Adoção
#      </a>
#     </li>
#     <li>
#      <a class="" href="/animais.aspx?cc=1484&amp;cn=ms-campo-grande&amp;finalidade=Procura-Perdido">
#       <i class="fa fa fa-binoculars">
#       </i>
#       Perdido
#      </a>
#     </li>
#     <li>
#      <a class="" href="/animais.aspx?cc=1484&amp;cn=ms-campo-grande&amp;finalidade=Encontrado">
#       <i class="fa fa fa-life-ring">
#       </i>
#       Encontrado
#      </a>
#     </li>
#     <li class="ultimo">
#      <a href="/busca.aspx?cc=1484&amp;cn=ms-campo-grande">
#       <i class="fa fa fa-search">
#       </i>
#       Busca
#      </a>
#     </li>
#    </ul>
#   </div>
#   <div id="avisa-cookie" style="display: none;">
#    Ao usar esse site você concorda com o uso de cookies e nossa política de privacidade.
#    <div class="botao">
#     Concordo
#    </div>
#   </div>
#   <script>
#   </script>
#   <script>
#    (function (i, s, o, g, r, a, m) {
#             i['GoogleAnalyticsObject'] = r; i[r] = i[r] || function () {
#                 (i[r].q = i[r].q || []).push(arguments)
#             }, i[r].l = 1 * new Date(); a = s.createElement(o),
#                 m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m)
#         })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#
#         ga('create', 'UA-24858037-2', 'auto');
#         ga('send', 'pageview');
#   </script>
#   <script async="" crossorigin="anonymous" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-1339485442487398">
#   </script>
#  </body>
# </html>

# %%
soup.html
# Out:
# <html lang="pt-br">
# <head><meta content="424936937573966" property="fb:app_id"/><meta content="website" property="og:type"/><meta content="pt-br" http-equiv="content-language"/><meta content="initial-scale=1.0" name="viewport"/><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><title>
# 	Cachorros para adoção em MS - Campo Grande - Procure 1 Amigo
# </title><meta content="Cachorros para adoção em MS - Campo Grande - Procure 1 Amigo" name="title"/><meta content="Veja Cachorros para adoção em MS - Campo Grande - Procure 1 Amigo - cachorros e gatos de ONGs de proteção animal do Brasil - Adoção, doação e procura de cães e gatos" name="description"/><meta content="Cachorros para adoção em MS - Campo Grande - Procure 1 Amigo" name="keywords"/><meta content="Cachorros para adoção em MS - Campo Grande - Procure 1 Amigo" name="og:title" property="og:title"/><meta content="Veja Cachorros para adoção em MS - Campo Grande - Procure 1 Amigo - cachorros e gatos de ONGs de proteção animal do Brasil - Adoção, doação e procura de cães e gatos" name="og:description" property="og:description"/><meta content="https://adotar.com.br/imagens/amigos-cao-e-gato-dfaff.jpg" name="og:image" property="og:image"/><meta content="https://adotar.com.br/animais.aspx?cc=1484&amp;cn=ms-campo-grande&amp;finalidade=Adocao&amp;tipo=Cao&amp;porte=Medio" name="og:url" property="og:url"/><meta content="Procure 1 Amigo" name="og:site_name" property="og:site_name"/><meta content="424936937573966" name="fb:app_id" property="fb:app_id"/><meta content="website" name="og:type" property="og:type"/><meta content="@procure1amigo" name="twitter:site"/><meta content="Cachorros para adoção em MS - Campo Grande - Procure 1 Amigo" name="twitter:title"/><meta content="Veja Cachorros para adoção em MS - Campo Grande - Procure 1 Amigo - cachorros e gatos de ONGs de proteção animal do Brasil - Adoção, doação e procura de cães e gatos" name="twitter:description"/><meta content="https://adotar.com.br/imagens/amigos-cao-e-gato-dfaff.jpg" name="twitter:image"/><meta content="Procure1Amigo" name="apple-mobile-web-app-title"/><link href="//adotar.com.br/icones/apple-touch-icon-196x196-precomposed.png" rel="shortcut icon" sizes="196x196"/><link href="//adotar.com.br/icones/apple-touch-icon-152x152-precomposed.png" rel="apple-touch-icon-precomposed" sizes="152x152"/><link href="//adotar.com.br/icones/apple-touch-icon-144x144-precomposed.png" rel="apple-touch-icon-precomposed" sizes="144x144"/><link href="//adotar.com.br/icones/apple-touch-icon-120x120-precomposed.png" rel="apple-touch-icon-precomposed" sizes="120x120"/><link href="//adotar.com.br/icones/apple-touch-icon-114x114-precomposed.png" rel="apple-touch-icon-precomposed" sizes="114x114"/><link href="//adotar.com.br/icones/apple-touch-icon-76x76-precomposed.png" rel="apple-touch-icon-precomposed" sizes="76x76"/><link href="//adotar.com.br/icones/apple-touch-icon-72x72-precomposed.png" rel="apple-touch-icon-precomposed" sizes="72x72"/><link href="//adotar.com.br/icones/apple-touch-icon-60x60-precomposed.png" rel="apple-touch-icon-precomposed" sizes="60x60"/><link href="//adotar.com.br/icones/apple-touch-icon-57x57-precomposed.png" rel="apple-touch-icon-precomposed" sizes="57x57"/><link href="//adotar.com.br/icones/apple-touch-icon-60x60-precomposed.png" rel="apple-touch-icon-precomposed"/><link href="//adotar.com.br/icones/apple-touch-icon-16x16-precomposed.png" rel="shortcut icon" sizes="16x16"/><link href="//adotar.com.br/icones/apple-touch-icon-76x76-precomposed.png" rel="apple-touch-icon" sizes="76x76"/><link href="//adotar.com.br/icones/apple-touch-icon-60x60-precomposed.png" rel="apple-touch-icon" sizes="60x60"/><link href="//adotar.com.br/icones/apple-touch-icon-60x60-precomposed.png" rel="apple-touch-icon"/><link href="//adotar.com.br/icones/iphoneSplashScreen.png" media="(device-width: 320px)" rel="apple-touch-startup-image"/><link href="//adotar.com.br/icones/iphone4SplashScreen.png" media="(device-width: 320px) and (-webkit-device-pixel-ratio: 2)" rel="apple-touch-startup-image"/><link href="//adotar.com.br/icones/iphone5SplashScreen.png" media="(device-height: 568px)" rel="apple-touch-startup-image"/><meta content="yes" name="apple-mobile-web-app-capable"/><meta content="yes" name="mobile-web-app-capable"/><meta content="black" name="apple-mobile-web-app-status-bar-style ...
# <script type="text/javascript">
#         var endereco = window.location.href;
#         var veioModal = false;
#         if (endereco != null && endereco.toLowerCase().includes("modal=1")) {
#             //console.log("veio modal");
#             veioModal = true;
#         }
#         else {
#
#             var googletag = googletag || {};
#             googletag.cmd = googletag.cmd || [];
#             (function () {
#                 var gads = document.createElement('script');
#                 gads.async = true;
#                 gads.type = 'text/javascript';
#                 var useSSL = 'https:' == document.location.protocol;
#                 gads.src = (useSSL ? 'https:' : 'http:') +
#                     '//www.googletagservices.com/tag/js/gpt.js';
#                 var node = document.getElementsByTagName('script')[0];
#                 node.parentNode.insertBefore(gads, node);
#             })();
#
#
#
#             googletag.cmd.push(function () {
#                 googletag.defineSlot('/75766867/Movel-Top', [320, 50], 'div-gpt-ad-1431185685094-0').addService(googletag.pubads());
#                 googletag.defineSlot('/75766867/MovelRodape', [300, 250], 'div-gpt-ad-1431185685094-1').addService(googletag.pubads());
#                 googletag.pubads().enableSingleRequest();
#                 googletag.enableServices();
#             });
#
#         }
#     </script>
# <script defer="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <link href="/manifest.json" rel="manifest"/>
# <link href="https://adotar.com.br/animais.aspx?cc=1484&amp;cn=ms-campo-grande&amp;finalidade=Adocao&amp;tipo=Cao&amp;porte=Medio" rel="canonical"/></head>
# <body id="Body">
# <div class="max-centraliza">
# <form action="./animais.aspx?cc=1484&amp;cn=ms-campo-grande&amp;finalidade=Adocao&amp;tipo=Cao&amp;porte=Medio" id="form1" method="post">
# <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="..."/>
# <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="736D0F40"/>
# <input id="__EVENTVALIDATION" name="__EVENTVALIDATION" type="hidden" value="..."/>
# <div id="boxTopo">
# <div class="max-centraliza">
# <img alt="Menu" border="0" id="botaoMenu" src="/imagens/menu_botao.png"/>
# <a href="/" id="HyperLinkLogo" title="Procure 1 Amigo - Animais para Adoção, doação e procura de cachorros e gatos"><img alt="Procure 1 Amigo - Animais para Adoção, doação e procura de cachorros e gatos" border="0" id="logo-procure-master" src="/imagens/logo.png"/></a>
# <div id="boxTopoDireita">
# <span id="LabelPaginaAtual"><i class="fa fa-heart"></i> <u>Adoção</u></span>
# </div>
# <!--<a title="Ajuda para adotar, doar e procurar" href='javascript:;' id="quero-ajuda"><i class="fa fa-question-circle" aria-hidden="true"></i></a>-->
# </div>
# </div>
# <div id="menuPrincipal">
# <ul>
# <li><a href="/?cc=1484&amp;cn=ms-campo-grande&amp;">Início</a></li>
# <!--<li><a href="painel">Cadastrar animal</a></li>-->
# <li><a href="/animais.aspx?cc=1484&amp;cn=ms-campo-grande&amp;finalidade=Adocao">Animais para adoção</a></li>
# <li><a href="/animais.aspx?cc=1484&amp;cn=ms-campo-grande&amp;finalidade=Procura-Perdido">Animais perdidos</a></li>
# <li><a href="/animais.aspx?cc=1484&amp;cn=ms-campo-grande&amp;finalidade=Encontrado">Animais encontrados</a></li>
# <li><a href="/busca.aspx?cc=1484&amp;cn=ms-campo-grande">Busca detalhada</a></li>
# <li><a href="/eventos.aspx">Eventos</a></li>
# <li><a href="https://loja.procure1amigo.com.br/" rel="noopener" target="_blank">Loja</a></li>
# <li><a href="/blog.aspx">Blog</a></li>
# <li><a href="/fale_conosco.aspx">Contato</a></li>
# <li><a href="/entrar.aspx">Cadastrar animal</a></li>
# <li><a href="/cadastro_finaliza.aspx">Ajude-nos</a></li>
# <li><a href="/quem_somos.aspx">Quem Somos</a></li>
# <!--<li><a href='//adotar.com.br/?fixa=1'>Site desktop</a></li>-->
# </ul>
# </div>
# <div id="boxConteudo">
# <script async="" crossorigin="anonymous" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-1339485442487398"></script>
# <!-- TopNovo -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-1339485442487398" data-ad-slot="4911295808" style="display:inline-block;width:990px;height:60px"></ins>
# <script>
#     (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# <div id="menuSuperiorh">
# <ul>
# <li><a class="" href="/?cc=1484&amp;cn=ms-campo-grande"><i class="fa fas fa-paw"></i>Home</a></li>
# <li><a class="" href="/entrar.aspx"><i class="fa fa fa-camera"></i>Postar</a></li>
# <li><a class="atual" href="/animais.aspx?cc=1484&amp;cn=ms-campo-grande&amp;finalidade=Adocao"><i class="fa fa fa-heart"></i>Adoção</a></li>
# <li><a class="" href="/animais.aspx?cc=1484&amp;cn=ms-campo-grande&amp;finalidade=Procura-Perdido"><i class="fa fa fa-binoculars"></i>Perdido</a></li>
# <li><a class="" href="/animais.aspx?cc=1484&amp;cn=ms-campo-grande&amp;finalidade=Encontrado"><i class="fa fa fa-life-ring"></i>Encontrado</a></li>
# <li class="ultimo"><a href="/busca.aspx?cc=1484&amp;cn=ms-campo-grande"><i class="fa fa fa-search"></i>Busca</a></li>
# </ul>
# </div>
# <script src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-5abf8ca2d6ab4aaa" type="text/javascript"></script>
# <div class="tituloSetor procurar"><strong>Cidade</strong> atual</div>
# <table cellspacing="0" id="ContentPlaceHolder1_ContentPlaceHolder1_FormViewCidade">
# <tr>
# <td colspan="2">
# <div id="mostraCidade">MS - Campo Grande (<a href="Default_escolher.aspx" id="ContentPlaceHolder1_ContentPlaceHolder1_FormViewCidade_HyperLinkCidadeTrocar">trocar</a>)</div>
# <input id="ContentPlaceHolder1_ContentPlaceHolder1_FormViewCidade_HiddenFieldCidade" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$FormViewCidade$HiddenFieldCidade" type="hidden" value="MS - Campo Grande"/>
# </td>
# </tr>
# </table>
# <span class="tituloSetor adocao" id="ContentPlaceHolder1_ContentPlaceHolder1_LabelTitulo">Pets para <strong>Adoção</strong><div class="addthis_inline_share_toolbox_36fw"></div></span>
# <ul class="boxCurvaGrande" id="listaFiltraTipo">
# <li class="titulo">Filtrar por:</li>
# <li class="cao">
# <a href="animais.aspx?cc=1484&amp;cn=ms-campo-grande&amp;finalidade=Adocao&amp;porte=Medio&amp;tipo=Cao" id="ContentPlaceHolder1_ContentPlaceHolder1_HyperLinkFiltroCao">Cão</a></li>
# <li class="gato">
# <a href="animais.aspx?cc=1484&amp;cn=ms-campo-grande&amp;finalidade=Adocao&amp;porte=Medio&amp;tipo=Gato" id="ContentPlaceHolder1_ContentPlaceHolder1_HyperLinkFiltroGato">Gato</a></li>
# </ul>
# <input id="HiddenFieldQtde" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$HiddenFieldQtde" type="hidden" value="20"/>
# <div class="timeline" id="updates">
# <div class="listaAnimais" data-animal="208783" data-idanimal="27b12b2021e10d08d57">
# <a href="/ms-campo-grande/cao/adocao/biscoito-e-nemo-macho-medio/208783" id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HyperLinkAnimal_0">
# <span class="listaAnimaisImagem">
# <div class="listaAnimaisImagemConteudo">
# <img border="0" src="//adotar.com.br/painel/upload/2021-12/animais_imagem792916.jpg"/>
# </div>
# </span>
# <div class="listaAnimaisDados">
#                             Biscoito e Nemo <span class="novo">Novo</span><br/>Macho / Médio<br/>2 a 6 meses
#                         </div>
# </a>
# <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldCod_0" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl00$HiddenFieldCod" type="hidden" value="27b12b2021e10d08d57"/>
# <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldLinkExterno_0" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl00$HiddenFieldLinkExterno" type="hidden"/>
# </div>
# <div class="listaAnimais" data-animal="208461" data-idanimal="20b12b2021e18d08d51">
# <a href="/ms-campo-grande/cao/adocao/kira-fox-paulistino-femea-medio/208461" id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HyperLinkAnimal_1">
# <span class="listaAnimaisImagem">
# <div class="listaAnimaisImagemConteudo">
# <img border="0" src="//adotar.com.br/painel/upload/2021-12/animais_imagem792086.jpg"/>
# </div>
# </span>
# <div class="listaAnimaisDados">
#                             Kira <span class="novo">Novo</span><br/>Femea / Médio<br/>2 anos
#                         </div>
# </a>
# <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldCod_1" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl01$HiddenFieldCod" type="hidden" value="20b12b2021e18d08d51"/>
# <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldLinkExterno_1" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl01$HiddenFieldLinkExterno" type="hidden"/>
# </div>
# <div class="listaAnimais" data-animal="207231" data-idanimal="01b12b2021e16d59d40">
# <a href="/ms-campo-grande/cao/adocao/chico-vira-lata-macho-medio/207231" id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HyperLinkAnimal_2">
# <span class="listaAnimaisImagem">
# <div class="listaAnimaisImagemConteudo">
# <img border="0" src="//adotar.com.br/painel/upload/2021-12/animais_imagem784680.jpg"/>
# </div>
# </span>
# <div class="listaAnimaisDados">
#                             CHICO <br/>Macho / Médio<br/>7 a 11 meses
#                         </div>
# </a>
# <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldCod_2" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl02$HiddenFieldCod" type="hidden" value="01b12b2021e16d59d40"/>
# <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldLinkExterno_2" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl02$HiddenFieldLinkExterno" type="hidden"/>
# </div>
# <div class="listaAnimais" data-animal="207062" data-idanimal="29b11b2021e12d20d24">
# <a href="/ms-campo-grande/cao/adocao/jade-srd-viralata-femea-medio/207062" id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HyperLinkAnimal_3">
# <span class="listaAnimaisImagem">
# <div class="listaAnimaisImagemConteudo">
# <img border="0" src="//adotar.com.br/painel/upload/2021-11/animais_imagem783861.jpg"/>
# </div>
# </span>
# <div class="listaAnimaisDados">
#                             jade <br/>Femea / Médio<br/>2 a 6 meses
#                         </div>
# </a>
# <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldCod_3" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl03$HiddenFieldCod" type="hidden" value="29b11b2021e12d20d24"/>
# <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldLinkExterno_3" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl03$HiddenFieldLinkExterno" type="hidden"/>
# </div>
# <div class="listaAnimais" data-animal="207054" data-idanimal="29b11b2021e11d28d37">
# <a href="/ms-campo-grande/cao/adocao/kira-fox-paulistino-femea-medio/207054" id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HyperLinkAnimal_4">
# <span class="listaAnimaisImagem">
# <div class="listaAnimaisImagemConteudo">
# <img border="0" src="//adotar.com.br/painel/upload/2021-11/animais_imagem783822.jpg"/>
# </div>
# </span>
# <div class="listaAnimaisDados">
#                             Kira <br/>Femea / Médio<br/>2 anos
#                         </div>
# </a>
# <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldCod_4" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ct
id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HyperLinkAnimal_14">
# <span class="listaAnimaisImagem">
# <div class="listaAnimaisImagemConteudo">
# <img border="0" src="//adotar.com.br/painel/upload/2021-07/animais_imagem736164.jpg"/>
# </div>
# </span>
# <div class="listaAnimaisDados">
#                             Sem nome <br/>Ambos / Médio<br/>2 a 6 meses
#                         </div>
# </a>
# <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldCod_14" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl14$HiddenFieldCod" type="hidden" value="11b07b2021e16d52d28"/>
# <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldLinkExterno_14" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl14$HiddenFieldLinkExterno" type="hidden"/>
# </div>
# <div class="listaAnimais" data-animal="195305" data-idanimal="25b06b2021e19d58d16">
# <a href="/ms-campo-grande/cao/encontrado/isa-femea-medio/195305" id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HyperLinkAnimal_15">
# <span class="listaAnimaisImagem">
# <div class="listaAnimaisImagemConteudo">
# <img border="0" src="//adotar.com.br/painel/upload/2021-06/animais_imagem730348.jpg"/>
# </div>
# </span>
# <div class="listaAnimaisDados">
#                             Isa <br/>Femea / Médio<br/>7 a 11 meses
#                         </div>
# </a>
# <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldCod_15" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl15$HiddenFieldCod" type="hidden" value="25b06b2021e19d58d16"/>
# <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldLinkExterno_15" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl15$HiddenFieldLinkExterno" type="hidden"/>
# </div>
# <div class="listaAnimais" data-animal="194153" data-idanimal="11b06b2021e13d46d43">
# <a href="/ms-campo-grande/cao/adocao/mike-e-fibe-vira-lata-macho-femea-medio/194153" id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HyperLinkAnimal_16">
# <span class="listaAnimaisImagem">
# <div class="listaAnimaisImagemConteudo">
# <img border="0" src="//adotar.com.br/painel/upload/2021-06/animais_imagem724465.jpg"/>
# </div>
# </span>
# <div class="listaAnimaisDados">
#                             Mike e Fibe <br/>Ambos / Médio<br/>1 ano
#                         </div>
# </a>
# <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldCod_16" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl16$HiddenFieldCod" type="hidden" value="11b06b2021e13d46d43"/>
# <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldLinkExterno_16" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl16$HiddenFieldLinkExterno" type="hidden"/>
# </div>
# <div class="listaAnimais" data-animal="192694" data-idanimal="05b06b2021e16d44d34">
# <a href="/ms-campo-grande/cao/adocao/kahli-nao-definida-femea-medio/192694" id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HyperLinkAnimal_17">
# <span class="listaAnimaisImagem">
# <div class="listaAnimaisImagemConteudo">
# <img border="0" src="//adotar.com.br/painel/upload/2021-06/animais_imagem721613.jpg"/>
# </div>
# </span>
# <div class="listaAnimaisDados">
#                             Kahli <br/>Femea / Médio<br/>3 anos
#                         </div>
# </a>
# <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldCod_17" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl17$HiddenFieldCod" type="hidden" value="05b06b2021e16d44d34"/>
# <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldLinkExterno_17" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl17$HiddenFieldLinkExterno" type="hidden"/>
# </div>
# <div class="listaAnimais" data-animal="192361" data-idanimal="01b06b2021e17d52d26">
# <a href="/ms-campo-grande/cao/adocao/luna-vira-lata-femea-medio/192361" id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HyperLinkAnimal_18">
# <span class="listaAnimaisImagem">
# <div class="listaAnimaisImagemConteudo">
# <img border="0" src="//adotar.com.br/painel/upload/2021-06/animais_imagem720102.jpg"/>
# </div>
# </span>
# <div class="listaAnimaisDados">
#                             Luna  <br/>Femea / Médio<br/>2 anos
#                         </div>
# </a>
# <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldCod_18" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl18$HiddenFieldCod" type="hidden" value="01b06b2021e17d52d26"/>
# <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldLinkExterno_18" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl18$HiddenFieldLinkExterno" type="hidden"/>
# </div>
# <div class="listaAnimais" data-animal="186860" data-idanimal="30b03b2021e22d58d57">
# <a href="/ms-campo-grande/cao/encontrado/perdida-femea-medio/186860" id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HyperLinkAnimal_19">
# <span class="listaAnimaisImagem">
# <div class="listaAnimaisImagemConteudo">
# <img border="0" src="//adotar.com.br/painel/upload/2021-03/animais_imagem694635.jpg"/>
# </div>
# </span>
# <div class="listaAnimaisDados">
#                             Perdida <br/>Femea / Médio<br/>
# </div>
# </a>
# <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldCod_19" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl19$HiddenFieldCod" type="hidden" value="30b03b2021e22d58d57"/>
# <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldLinkExterno_19" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl19$HiddenFieldLinkExterno" type="hidden"/>
# </div>
# <div id="outras-cidades"></div>
# <div class="paragrafo mt-10 mb-10">
# <!-- AnimaisNovoCentro -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-1339485442487398" data-ad-format="auto" data-ad-slot="7712062420" data-full-width-responsive="true" style="display: block"></ins>
# <script>
#                 (adsbygoogle = window.adsbygoogle || []).push({});
#             </script>
# </div>
# <div class="boxFinal" data-ultimoid="" id="box-final" style="text-align: center;">
# <a class="pegaMaisAnimais" href="javascript:selecionaMaisDesce(this);">Ver mais animais</a> | <a class="botaoFinalMudaCidade" href="/Default_escolher.aspx">Trocar cidade</a>
# </div>
# </div>
# <a href="animais.aspx?cc=1484&amp;cn=ms-campo-grande&amp;finalidade=Adocao&amp;porte=Medio&amp;semfoto=1" id="ContentPlaceHolder1_ContentPlaceHolder1_HyperLinkFiltroSemFoto"><b><font color="Black">ver animais sem foto</font></b></a>
# </div>
# <div style="position: relative; margin: auto; padding: 10px; margin-top: 20px;">
# <!-- RodapeNovo -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-1339485442487398" data-ad-format="auto" data-ad-slot="7321836728" data-full-width-responsive="true" style="display: block"></ins>
# <script>
#                     (adsbygoogle = window.adsbygoogle || []).push({});
#                 </script>
# </div>
# </form>
# </div>
# <script src="/js/jquery-3.6.0.min.js"></script>
# <script crossorigin="anonymous" src="https://kit.fontawesome.com/fd253adfbf.js"></script>
# <script src="https://www.gstatic.com/firebasejs/9.0.2/firebase-app-compat.js"></script>
# <script src="https://www.gstatic.com/firebasejs/9.0.2/firebase-messaging-compat.js"></script>
# <script src="https://www.gstatic.com/firebasejs/9.0.2/firebase-analytics-compat.js"></script>
# <script>
#
#
#         // Your web app's Firebase configuration
#         var firebaseConfig = {
#             apiKey: "AIzaSyDTFxzxe2lrkLI6cDj3vFfcupmjWkpl7Bk",
#             authDomain: "procure-1-amigo.firebaseapp.com",
#             databaseURL: "https://procure-1-amigo.firebaseio.com",
#             projectId: "procure-1-amigo",
#             storageBucket: "procure-1-amigo.appspot.com",
#             messagingSenderId: "999121279276",
#             appId: "1:999121279276:web:3f1782e6435fbd2961f489",
#             measurementId: "G-2E8HWL7RW0"
#         };
#         // Initialize Firebase
#         firebase.initializeApp(firebaseConfig);
#         firebase.analytics();
#
#     </script>
# <script src="/js/basicos.js"></script>
# <script type="text/javascript">
#         var vazio = false;
#         var ID = "";
#         var animais = "";
#         var trabalhando = false;
#
#         var cidade = getParameterByName('cc');
#         if (cidade == null || cidade == "")
#             cidade = "5214";
#
#         var querys = "cc=" + cidade;
#         if (getParameterByName('tipo') != null || getParameterByName('tipo') == "")
#             querys += "&tipo=" + getParameterByName('tipo');
#
#         if (getParameterByName('sexo') != null || getParameterByName('sexo') == "")
#             querys += "&sexo=" + getParameterByName('sexo');
#
#         if (getParameterByName('porte') != null || getParameterByName('porte') == "")
#             querys += "&porte=" + getParameterByName('porte');
#
#         if (getParameterByName('idade') != null || getParameterByName('idade') == "")
#             querys += "&idade=" + getParameterByName('idade');
#
#         if (getParameterByName('finalidade') != null || getParameterByName('finalidade') == "")
#             querys += "&finalidade=" + getParameterByName('finalidade');
#
#         if (getParameterByName('nome') != null || getParameterByName('nome') == "")
#             querys += "&nome=" + getParameterByName('nome');
#
#         if (getParameterByName('semfoto') != null || getParameterByName('semfoto') == "")
#             querys += "&semfoto=" + getParameterByName('semfoto');
#
#
#
#         function pegaID() {
#             $(".listaAnimais").each(function (index) {
#                 ID = $(this).data('idanimal');
#
#                 animais = animais + "-" + $(this).data('animal');
#             });
#         }
#
#         pegaID();
#
#
#         function selecionaMais() {
#
#             if (ID && !trabalhando) {
#                 $(".boxFinal").show('');
#                 $(".boxFinal").html('&nbsp;Buscando mais animais <i class="fa fa-circle-o-notch fa-spin"></i>.');
#
#                 var pagina = '/animais_jquery.aspx';
#
#                 if (vazio)
#                     pagina = '/animais_proximos.aspx';
#
#                 trabalhando = true;
#
#                 //console.log(querys);
#
#                 //data: querys + '&lastmsg=' + ID + '&animais=' + animais,
#                 $.ajax({
#                     type: "GET",
#                     url: pagina,
#                     data: querys + '&lastmsg=' + ID,
#                     cache: false,
#                     success: function (html) {
#                         $("div#updates").append(html.substring(html.indexOf('table') - 5).replace("</form>", ""));
#                         //$(".boxFinal").html('&nbsp;Veja mais animais <i class="fa fa-arrow-down" aria-hidden="true"></i>');
#                         //$(".boxFinal").hide();
#
#                         if (pagina == '/animais_proximos.aspx') {
#                             $(".boxFinal").html('&nbsp;Animais de outra cidade <i class="fa fa-arrow-down" aria-hidden="true"></i>');
#                             $(".boxFinal").show();
#                         }
#                         else
#                             $('.boxFinal').not(':last').remove();
#
#
#
#                         pegaID();
#                         trabalhando = false;
#
#                         //str.includes("wodrld")
#
#                         if (!html.includes("listaAnimaisDados")) {
#                             vazio = true;
#                             selecionaMais();
#                         }
#                     }
#                 });
#
#
#             }
#             else {
#                 $(".morebox").html('');
#             }
#
#             return false;
#         };
#
#
#         $(window).scroll(function () {
#             if (document.body.scrollHeight - $(this).scrollTop() - 2000 <= $(this).height()) {
#                 selecionaMais();
#             }
#         });
#
#         function selecionaMaisDesce(sender) {
#             selecionaMais();
#
#             $('html, body').animate({
#                 scrollTop: $("#" + sender).offset().top
#             }, 1000);
#         }
#
#
#
#
#
#
#
#         $(document).ready(function () {
#             var qtdeAnimais = parseFloat($("#HiddenFieldQtde").val());
#
#             if (qtdeAnimais < 20) {
#                 $(".boxFinal").show('');
#
#
#                 vazio = true;
#                 $(".boxFinal").html('&nbsp;Buscando animais próximos <i class="fa fa-circle-o-notch fa-spin"></i>.');
#
#                 $.ajax({
#                     type: "GET",
#                     url: "/animais_proximos.aspx",
#                     data: querys + '&animais=' + animais,
#                     cache: false,
#                     success: function (html) {
#                         $("#outras-cidades").append(html.substring(html.indexOf('table') - 5).replace("</form>", ""));
#                         $("#achou-nenhum").text('');
#                         $(".boxFinal").html('Animais próximos <i class="fa fa-arrow-down" aria-hidden="true"></i>');
#
#                         pegaID();
#                     }
#                 });
#             }
#
#         });
#
#
#         function getParameterByName(name, url) {
#             if (!url) url = window.location.href;
#             name = name.replace(/[\[\]]/g, '\\$&');
#             var regex = new RegExp('[?&]' + name + '(=([^&#]*)|&|#|$)'),
#                 results = regex.exec(url);
#             if (!results) return null;
#             if (!results[2]) return '';
#             return decodeURIComponent(results[2].replace(/\+/g, ' '));
#         }
#     </script>
# <div style="height: 30px;"></div>
# <div id="menuInferior">
# <ul>
# <li><a class="" href="/?cc=1484&amp;cn=ms-campo-grande"><i class="fa fas fa-paw"></i>Home</a></li>
# <li><a class="" href="/entrar.aspx"><i class="fa fa fa-camera"></i>Postar</a></li>
# <li><a class="atual" href="/animais.aspx?cc=1484&amp;cn=ms-campo-grande&amp;finalidade=Adocao"><i class="fa fa fa-heart"></i>Adoção</a></li>
# <li><a class="" href="/animais.aspx?cc=1484&amp;cn=ms-campo-grande&amp;finalidade=Procura-Perdido"><i class="fa fa fa-binoculars"></i>Perdido</a></li>
# <li><a class="" href="/animais.aspx?cc=1484&amp;cn=ms-campo-grande&amp;finalidade=Encontrado"><i class="fa fa fa-life-ring"></i>Encontrado</a></li>
# <li class="ultimo"><a href="/busca.aspx?cc=1484&amp;cn=ms-campo-grande"><i class="fa fa fa-search"></i>Busca</a></li>
# </ul>
# </div>
# <div id="avisa-cookie" style="display: none;">
#         Ao usar esse site você concorda com o uso de cookies e nossa política de privacidade.
#         <div class="botao">
#             Concordo
#         </div>
# </div>
# <script>
# </script>
# <script>
#
#         (function (i, s, o, g, r, a, m) {
#             i['GoogleAnalyticsObject'] = r; i[r] = i[r] || function () {
#                 (i[r].q = i[r].q || []).push(arguments)
#             }, i[r].l = 1 * new Date(); a = s.createElement(o),
#                 m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m)
#         })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#
#         ga('create', 'UA-24858037-2', 'auto');
#         ga('send', 'pageview');
#
#     </script>
# <script async="" crossorigin="anonymous" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-1339485442487398"></script>
# </body>
# </html>

# %%
soup.findAll('img')
# Out:
# [<img alt="Menu" border="0" id="botaoMenu" src="/imagens/menu_botao.png"/>,
#  <img alt="Procure 1 Amigo - Animais para Adoção, doação e procura de cachorros e gatos" border="0" id="logo-procure-master" src="/imagens/logo.png"/>,
#  <img border="0" src="//adotar.com.br/painel/upload/2021-12/animais_imagem792916.jpg"/>,
#  <img border="0" src="//adotar.com.br/painel/upload/2021-12/animais_imagem792086.jpg"/>,
#  <img border="0" src="//adotar.com.br/painel/upload/2021-12/animais_imagem784680.jpg"/>,
#  <img border="0" src="//adotar.com.br/painel/upload/2021-11/animais_imagem783861.jpg"/>,
#  <img border="0" src="//adotar.com.br/painel/upload/2021-11/animais_imagem783822.jpg"/>,
#  <img border="0" src="//adotar.com.br/painel/upload/2021-11/animais_imagem783747.jpg"/>,
#  <img border="0" src="//adotar.com.br/painel/upload/2021-11/animais_imagem779552.jpg"/>,
#  <img border="0" src="//adotar.com.br/painel/upload/2021-11/animais_imagem778806.jpg"/>,
#  <img border="0" src="//adotar.com.br/painel/upload/2021-11/animais_imagem777753.jpg"/>,
#  <img border="0" src="//adotar.com.br/painel/upload/2021-09/animais_imagem761568.jpg"/>,
#  <img border="0" src="//adotar.com.br/painel/upload/2021-09/animais_imagem755919.jpg"/>,
#  <img border="0" src="//adotar.com.br/painel/upload/2021-09/animais_imagem754477.jpg"/>,
#  <img border="0" src="//adotar.com.br/painel/upload/2021-08/animais_imagem751631.jpg"/>,
#  <img border="0" src="//adotar.com.br/painel/upload/2021-08/animais_imagem747606.jpg"/>,
#  <img border="0" src="//adotar.com.br/painel/upload/2021-07/animais_imagem736164.jpg"/>,
#  <img border="0" src="//adotar.com.br/painel/upload/2021-06/animais_imagem730348.jpg"/>,
#  <img border="0" src="//adotar.com.br/painel/upload/2021-06/animais_imagem724465.jpg"/>,
#  <img border="0" src="//adotar.com.br/painel/upload/2021-06/animais_imagem721613.jpg"/>,
#  <img border="0" src="//adotar.com.br/painel/upload/2021-06/animais_imagem720102.jpg"/>,
#  <img border="0" src="//adotar.com.br/painel/upload/2021-03/animais_imagem694635.jpg"/>]

# %%
soup.findAll('img', limit = 22)[2:]
for item in soup.findAll('img', limit=22)[2:]:
    print(item.get('src'))
# Out:
# //adotar.com.br/painel/upload/2021-12/animais_imagem792916.jpg
# //adotar.com.br/painel/upload/2021-12/animais_imagem792086.jpg
# //adotar.com.br/painel/upload/2021-12/animais_imagem784680.jpg
# //adotar.com.br/painel/upload/2021-11/animais_imagem783861.jpg
# //adotar.com.br/painel/upload/2021-11/animais_imagem783822.jpg
# //adotar.com.br/painel/upload/2021-11/animais_imagem783747.jpg
# //adotar.com.br/painel/upload/2021-11/animais_imagem779552.jpg
# //adotar.com.br/painel/upload/2021-11/animais_imagem778806.jpg
# //adotar.com.br/painel/upload/2021-11/animais_imagem777753.jpg
#                          </div>
#  </a>
#  <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldCod_14" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl14$HiddenFieldCod" type="hidden" value="11b07b2021e16d52d28"/>
#  <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldLinkExterno_14" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl14$HiddenFieldLinkExterno" type="hidden"/>
#  </div>,
#  <div class="listaAnimais" data-animal="195305" data-idanimal="25b06b2021e19d58d16">
#  <a href="/ms-campo-grande/cao/encontrado/isa-femea-medio/195305" id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HyperLinkAnimal_15">
#  <span class="listaAnimaisImagem">
#  <div class="listaAnimaisImagemConteudo">
#  <img border="0" src="//adotar.com.br/painel/upload/2021-06/animais_imagem730348.jpg"/>
#  </div>
#  </span>
#  <div class="listaAnimaisDados">
#                              Isa <br/>Femea / Médio<br/>7 a 11 meses
#                          </div>
#  </a>
#  <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldCod_15" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl15$HiddenFieldCod" type="hidden" value="25b06b2021e19d58d16"/>
#  <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldLinkExterno_15" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl15$HiddenFieldLinkExterno" type="hidden"/>
#  </div>,
#  <div class="listaAnimais" data-animal="194153" data-idanimal="11b06b2021e13d46d43">
#  <a href="/ms-campo-grande/cao/adocao/mike-e-fibe-vira-lata-macho-femea-medio/194153" id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HyperLinkAnimal_16">
#  <span class="listaAnimaisImagem">
#  <div class="listaAnimaisImagemConteudo">
#  <img border="0" src="//adotar.com.br/painel/upload/2021-06/animais_imagem724465.jpg"/>
#  </div>
#  </span>
#  <div class="listaAnimaisDados">
#                              Mike e Fibe <br/>Ambos / Médio<br/>1 ano
#                          </div>
#  </a>
#  <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldCod_16" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl16$HiddenFieldCod" type="hidden" value="11b06b2021e13d46d43"/>
#  <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldLinkExterno_16" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl16$HiddenFieldLinkExterno" type="hidden"/>
#  </div>,
#  <div class="listaAnimais" data-animal="192694" data-idanimal="05b06b2021e16d44d34">
#  <a href="/ms-campo-grande/cao/adocao/kahli-nao-definida-femea-medio/192694" id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HyperLinkAnimal_17">
#  <span class="listaAnimaisImagem">
#  <div class="listaAnimaisImagemConteudo">
#  <img border="0" src="//adotar.com.br/painel/upload/2021-06/animais_imagem721613.jpg"/>
#  </div>
#  </span>
#  <div class="listaAnimaisDados">
#                              Kahli <br/>Femea / Médio<br/>3 anos
#                          </div>
#  </a>
#  <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldCod_17" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl17$HiddenFieldCod" type="hidden" value="05b06b2021e16d44d34"/>
#  <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldLinkExterno_17" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl17$HiddenFieldLinkExterno" type="hidden"/>
#  </div>,
#  <div class="listaAnimais" data-animal="192361" data-idanimal="01b06b2021e17d52d26">
#  <a href="/ms-campo-grande/cao/adocao/luna-vira-lata-femea-medio/192361" id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HyperLinkAnimal_18">
#  <span class="listaAnimaisImagem">
#  <div class="listaAnimaisImagemConteudo">
#  <img border="0" src="//adotar.com.br/painel/upload/2021-06/animais_imagem720102.jpg"/>
#  </div>
#  </span>
#  <div class="listaAnimaisDados">
#                              Luna  <br/>Femea / Médio<br/>2 anos
#                          </div>
#  </a>
#  <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldCod_18" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl18$HiddenFieldCod" type="hidden" value="01b06b2021e17d52d26"/>
#  <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldLinkExterno_18" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl18$HiddenFieldLinkExterno" type="hidden"/>
#  </div>,
#  <div class="listaAnimais" data-animal="186860" data-idanimal="30b03b2021e22d58d57">
#  <a href="/ms-campo-grande/cao/encontrado/perdida-femea-medio/186860" id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HyperLinkAnimal_19">
#  <span class="listaAnimaisImagem">
#  <div class="listaAnimaisImagemConteudo">
#  <img border="0" src="//adotar.com.br/painel/upload/2021-03/animais_imagem694635.jpg"/>
#  </div>
#  </span>
#  <div class="listaAnimaisDados">
#                              Perdida <br/>Femea / Médio<br/>
#  </div>
#  </a>
#  <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldCod_19" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl19$HiddenFieldCod" type="hidden" value="30b03b2021e22d58d57"/>
#  <input id="ContentPlaceHolder1_ContentPlaceHolder1_Repeater1_HiddenFieldLinkExterno_19" name="ctl00$ctl00$ContentPlaceHolder1$ContentPlaceHolder1$Repeater1$ctl19$HiddenFieldLinkExterno" type="hidden"/>
#  </div>]

# %%
for item in res:
    link = item.find('a')['href']
    link = 'https://adotar.com.br'+link
    image = item.find('img')
    text = item.find('div',{'class':'listaAnimaisDados'})
    text = text.get_text().split()
    print(link)
    print(text[0])
    print(image)
# Out:
# https://adotar.com.br/ms-campo-grande/cao/adocao/biscoito-e-nemo-macho-medio/208783
# Biscoito
# <img border="0" src="//adotar.com.br/painel/upload/2021-12/animais_imagem792916.jpg"/>
# https://adotar.com.br/ms-campo-grande/cao/adocao/kira-fox-paulistino-femea-medio/208461
# Kira
# <img border="0" src="//adotar.com.br/painel/upload/2021-12/animais_imagem792086.jpg"/>
# https://adotar.com.br/ms-campo-grande/cao/adocao/chico-vira-lata-macho-medio/207231
# CHICO
# <img border="0" src="//adotar.com.br/painel/upload/2021-12/animais_imagem784680.jpg"/>
# https://adotar.com.br/ms-campo-grande/cao/adocao/jade-srd-viralata-femea-medio/207062
# jade
# <img border="0" src="//adotar.com.br/painel/upload/2021-11/animais_imag